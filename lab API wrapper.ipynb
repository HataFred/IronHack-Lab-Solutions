# %% [markdown]
# ## Spotipy API
#
# Create an Spotify account and follow these steps to register an app: https://developer.spotify.com/documentation/general/guides/app-settings/
#
# After the app is created, you can see it on your dashboard
# https://developer.spotify.com/dashboard/applications
#
# Click on it and you'll find the client id and client secret.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#some extra useful libraries
import pandas as pd
import json
import pprint
import getpass

# %%
client_id = getpass.getpass(prompt="Spotify client_id: ")
client_secret = getpass.getpass(prompt="Spotify client_secret: ")

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id=client_id,
    client_secret=client_secret)
                    )
# Out:
# Spotify client_id: ········
# Spotify client_secret: ········

# %%
#Quick test - Searching songs with 'queries' with sp.search

results = sp.search(q='The Weeknd', limit=50)
results

#(reminder- raw output will be json 
#this feels like a good time to look at the documentation!)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=The+Weeknd&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#      'href': 'https://api.spotify.com/v1/albums/4yP0hdKOZPNshxUOjY0cZj',
#      'id': '4yP0hdKOZPNshxUOjY0cZj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738863bc11d2aa12b54f5aeb36',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028863bc11d2aa12b54f5aeb36',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518863bc11d2aa12b54f5aeb36',
#        'width': 64}],
#      'name': 'After Hours',
#      'release_date': '2020-03-20',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:4yP0hdKOZPNshxUOjY0cZj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 200040,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG11904206'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b'},
#     'href': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b',
#     'id': '0VjIjW4GlUZAMYd2vXMi3b',
#     'is_local': False,
#     'name': 'Blinding Lights',
#     'popularity': 96,
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:0VjIjW4GlUZAMYd2vXMi3b'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1r4hJ1h58CWwUQe3MxPuau'},
#        'href': 'https://api.spotify.com/v1/artists/1r4hJ1h58CWwUQe3MxPuau',
#        'id': '1r4hJ1h58CWwUQe3MxPuau',
#        'name': 'Maluma',
#        'type': 'artist',
#        'uri': 'spotify:artist:1r4hJ1h58CWwUQe3MxPuau'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1Ag9EPbzibwzz0S0WpgX3v'},
#      'href': 'https://api.spotify.com/v1/albums/1Ag9EPbzibwzz0S0WpgX3v',
#      'id': '1Ag9EPbzibwzz0S0WpgX3v',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273be768155351bbd7d4c19ab13',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02be768155351bbd7d4c19ab13',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851be768155351bbd7d4c19ab13',
#        'width': 64}],
#      'name': 'Hawái (Remix)',
#      'release_date': '2020-11-05',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1Ag9EPbzibwzz0S0WpgX3v'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1r4hJ1h58CWwUQe3MxPuau'},
#       'href': 'https://api.spotify.com/v1/artists/1r4hJ1h58CWwUQe3MxPuau',
#       'id': '1r4hJ1h58CWwUQe3MxPuau',
#       'name': 'Maluma',
#       'type': 'artist',
#       'uri': 'spotify:artist:1r4hJ1h58CWwUQe3MxPuau'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 200481,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSD12000526'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0GzuHFG4Ql6DoyxFRnIk3F'},
#     'href': 'https://api.spotify.com/v1/tracks/0GzuHFG4Ql6DoyxFRnIk3F',
#     'id': '0GzuHFG4Ql6DoyxFRnIk3F',
#     'is_local': False,
#     'name': 'Hawái - Remix',
#     'popularity': 90,
#     'preview_url': 'https://p.scdn.co/mp3-preview/387b491a7a8a2200379386e98f2f4a95506bb107?cid=c39fbc66489441ce809290f1c586c0db',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0GzuHFG4Ql6DoyxFRnIk3F'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#        'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#        'id': '66CXWjxzNUsdJxJ2JdwvnR',
#        'name': 'Ariana Grande',
#        'type': 'artist',
#        'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3euz4vS7ezKGnNSwgyvKcd'},
#      'href': 'https://api.spotify.com/v1/albums/3euz4vS7ezKGnNSwgyvKcd',
#      'id': '3euz4vS7ezKGnNSwgyvKcd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735ef878a782c987d38d82b605',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025ef878a782c987d38d82b605',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515ef878a782c987d38d82b605',
#        'width': 64}],
#      'name': 'Positions',
#      'release_date': '2020-10-30',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:3euz4vS7ezKGnNSwgyvKcd'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#       'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#       'id': '66CXWjxzNUsdJxJ2JdwvnR',
#       'name': 'Ariana Grande',
#       'type': 'artist',
#       'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 239949,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72020429'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7E1jVNoWuemqUryI4FxsVD'},
#     'href': 'https://api.spotify.com/v1/tracks/7E1jVNoWuemqUryI4FxsVD',
#     'id': '7E1jVNoWuemqUryI4FxsVD',
#     'is_local': False,
#     'name': 'off the table (with The Weeknd)',
#     'popularity': 84,
#     'preview_url': None,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7E1jVNoWuemqUryI4FxsVD'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MCBfE4596Uoi2O4DtmEMz'},
#        'href': 'https://api.spotify.com/v1/artists/4MCBfE4596Uoi2O4DtmEMz',
#        'id': '4MCBfE4596Uoi2O4DtmEMz',
#        'name': 'Juice WRLD',
#        'type': 'artist',
#        'uri': 'spotify:artist:4MCBfE4596Uoi2O4DtmEMz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6n9DKpOxwifT5hOXtgLZSL'},
#      'href': 'https://api.spotify.com/v1/albums/6n9DKpOxwifT5hOXtgLZSL',
#      'id': '6n9DKpOxwifT5hOXtgLZSL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733e0698e4ae5ffb82a005aeeb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023e0698e4ae5ffb82a005aeeb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513e0698e4ae5ffb82a005aeeb',
#        'width': 64}],
#      'name': 'Legends Never Die',
#      'release_date': '2020-07-10',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:6n9DKpOxwifT5hOXtgLZSL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MCBfE4596Uoi2O4DtmEMz'},
#       'href': 'https://api.spotify.com/v1/artists/4MCBfE4596Uoi2O4DtmEMz',
#       'id': '4MCBfE4596Uoi2O4DtmEMz',
#       'name': 'Juice WRLD',
#       'type': 'artist',
#       'uri': 'spotify:artist:4MCBfE4596Uoi2O4DtmEMz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 196180,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG12002597'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6wQlQrTY5mVS8EGaFZVwVF'},
#     'href': 'https://api.spotify.com/v1/tracks/6wQlQrTY5mVS8EGaFZVwVF',
#     'id': '6wQlQrTY5mVS8EGaFZVwVF',
#     'is_local': False,
#     'name': 'Smile (with The Weeknd)',
#     'popularity': 83,
#     'preview_url': None,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:6wQlQrTY5mVS8EGaFZVwVF'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0P3oVJBFOv3TDXlYRhGL7s'},
#      'href': 'https://api.spotify.com/v1/albums/0P3oVJBFOv3TDXlYRhGL7s',
#      'id': '0P3oVJBFOv3TDXlYRhGL7s',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737fcead687e99583072cc217b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027fcead687e99583072cc217b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517fcead687e99583072cc217b',
#        'width': 64}],
#      'name': 'Beauty Behind The Madness',
#      'release_date': '2015-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0P3oVJBFOv3TDXlYRhGL7s'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 242253,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG11500737'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7fBv7CLKzipRk6EC6TWHOB'},
#     'href': 'https://api.spotify.com/v1/tracks/7fBv7CLKzipRk6EC6TWHOB',
#     'id': '7fBv7CLKzipRk6EC6TWHOB',
#     'is_local': False,
#     'name': 'The Hills',
#     'popularity': 83,
#     'preview_url': None,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7fBv7CLKzipRk6EC6TWHOB'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#      'href': 'https://api.spotify.com/v1/albums/2ODvWsOgouMbaA5xf0RkJe',
#      'id': '2ODvWsOgouMbaA5xf0RkJe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734718e2b124f79258be7bc452',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024718e2b124f79258be7bc452',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514718e2b124f79258be7bc452',
#        'width': 64}],
#      'name': 'Starboy',
#      'release_date': '2016-11-25',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:2ODvWsOgouMbaA5xf0RkJe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 230453,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG11600976'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7MXVkk9YMctZqd1Srtv4MB'},
#     'href': 'https://api.spotify.com/v1/tracks/7MXVkk9YMctZqd1Srtv4MB',
#     'id': '7MXVkk9YMctZqd1Srtv4MB',
#     'is_local': False,
#     'name': 'Starboy',
#     'popularity': 83,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7MXVkk9YMctZqd1Srtv4MB'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#      'href': 'https://api.spotify.com/v1/albums/4yP0hdKOZPNshxUOjY0cZj',
#      'id': '4yP0hdKOZPNshxUOjY0cZj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738863bc11d2aa12b54f5aeb36',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028863bc11d2aa12b54f5aeb36',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518863bc11d2aa12b54f5aeb36',
#        'width': 64}],
#      'name': 'After Hours',
#      'release_date': '2020-03-20',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:4yP0hdKOZPNshxUOjY0cZj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 198266,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG11904007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6bnF93Rx87YqUBLSgjiMU8'},
#     'href': 'https://api.spotify.com/v1/tracks/6bnF93Rx87YqUBLSgjiMU8',
#     'id': '6bnF93Rx87YqUBLSgjiMU8',
#     'is_local': False,
#     'name': 'Heartless',
#     'popularity': 80,
#     'preview_url': None,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:6bnF93Rx87YqUBLSgjiMU8'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#      'href': 'https://api.spotify.com/v1/albums/4yP0hdKOZPNshxUOjY0cZj',
#      'id': '4yP0hdKOZPNshxUOjY0cZj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738863bc11d2aa12b54f5aeb36',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028863bc11d2aa12b54f5aeb36',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518863bc11d2aa12b54f5aeb36',
#        'width': 64}],
#      'name': 'After Hours',
#      'release_date': '2020-03-20',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:4yP0hdKOZPNshxUOjY0cZj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 237520,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG12000657'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7szuecWAPwGoV1e5vGu8tl'},
#     'href': 'https://api.spotify.com/v1/tracks/7szuecWAPwGoV1e5vGu8tl',
#     'id': '7szuecWAPwGoV1e5vGu8tl',
#     'is_local': False,
#     'name': 'In Your Eyes',
#     'popularity': 85,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:7szuecWAPwGoV1e5vGu8tl'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4qZBW3f2Q8y0k1A84d4iAO'},
#      'href': 'https://api.spotify.com/v1/albums/4qZBW3f2Q8y0k1A84d4iAO',
#      'id': '4qZBW3f2Q8y0k1A84d4iAO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731f6a2a40bb692936879db730',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021f6a2a40bb692936879db730',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511f6a2a40bb692936879db730',
#        'width': 64}],
#      'name': 'My Dear Melancholy,',
#      'release_date': '2018-03-30',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:4qZBW3f2Q8y0k1A84d4iAO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 228373,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG11800560'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/09mEdoA6zrmBPgTEN5qXmN'},
#     'href': 'https://api.spotify.com/v1/tracks/09mEdoA6zrmBPgTEN5qXmN',
#     'id': '09mEdoA6zrmBPgTEN5qXmN',
#     'is_local': False,
#     'name': 'Call Out My Name',
#     'popularity': 81,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:09mEdoA6zrmBPgTEN5qXmN'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7c0XG5cIJTrrAgEC3ULPiq'},
#        'href': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq',
#        'id': '7c0XG5cIJTrrAgEC3ULPiq',
#        'name': 'Ty Dolla $ign',
#        'type': 'artist',
#        'uri': 'spotify:artist:7c0XG5cIJTrrAgEC3ULPiq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3SHx7bBQFI4J8QRr6D5cOK'},
#      'href': 'https://api.spotify.com/v1/albums/3SHx7bBQFI4J8QRr6D5cOK',
#      'id': '3SHx7bBQFI4J8QRr6D5cOK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731c04efd2804b16cf689de7f0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021c04efd2804b16cf689de7f0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511c04efd2804b16cf689de7f0',
#        'width': 64}],
#      'name': 'Or Nah (feat. The Weeknd, Wiz Khalifa & DJ Mustard) [Remix]',
#      'release_date': '2014-06-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3SHx7bBQFI4J8QRr6D5cOK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7c0XG5cIJTrrAgEC3ULPiq'},
#       'href': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq',
#       'id': '7c0XG5cIJTrrAgEC3ULPiq',
#       'name': 'Ty Dolla $ign',
#       'type': 'artist',
#       'uri': 'spotify:artist:7c0XG5cIJTrrAgEC3ULPiq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/137W8MRPWKqSmrBGDBFSop'},
#       'href': 'https://api.spotify.com/v1/artists/137W8MRPWKqSmrBGDBFSop',
#       'id': '137W8MRPWKqSmrBGDBFSop',
#       'name': 'Wiz Khalifa',
#       'type': 'artist',
#       'uri': 'spotify:artist:137W8MRPWKqSmrBGDBFSop'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0YinUQ50QDB7ZxSCLyQ40k'},
#       'href': 'https://api.spotify.com/v1/artists/0YinUQ50QDB7ZxSCLyQ40k',
#       'id': '0YinUQ50QDB7ZxSCLyQ40k',
#       'name': 'Mustard',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YinUQ50QDB7ZxSCLyQ40k'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 242983,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT21401391'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7t2bFihaDvhIrd2gn2CWJO'},
#     'href': 'https://api.spotify.com/v1/tracks/7t2bFihaDvhIrd2gn2CWJO',
#     'id': '7t2bFihaDvhIrd2gn2CWJO',
#     'is_local': False,
#     'name': 'Or Nah (feat. The Weeknd, Wiz Khalifa & DJ Mustard) - Remix',
#     'popularity': 79,
#     'preview_url': 'https://p.scdn.co/mp3-preview/70f126c139847335bc03c756c55b80c99892268e?cid=c39fbc66489441ce809290f1c586c0db',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7t2bFihaDvhIrd2gn2CWJO'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#      'href': 'https://api.spotify.com/v1/albums/4yP0hdKOZPNshxUOjY0cZj',
#      'id': '4yP0hdKOZPNshxUOjY0cZj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738863bc11d2aa12b54f5aeb36',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028863bc11d2aa12b54f5aeb36',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518863bc11d2aa12b54f5aeb36',
#        'width': 64}],
#      'name': 'After Hours',
#      'release_date': '2020-03-20',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:4yP0hdKOZPNshxUOjY0cZj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
# ...
#     'popularity': 71,
#     'preview_url': None,
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:38uNCW1do0LKfMIt4MDkPo'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#      'href': 'https://api.spotify.com/v1/albums/2ODvWsOgouMbaA5xf0RkJe',
#      'id': '2ODvWsOgouMbaA5xf0RkJe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734718e2b124f79258be7bc452',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024718e2b124f79258be7bc452',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514718e2b124f79258be7bc452',
#        'width': 64}],
#      'name': 'Starboy',
#      'release_date': '2016-11-25',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:2ODvWsOgouMbaA5xf0RkJe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#       'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#       'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#       'name': 'Kendrick Lamar',
#       'type': 'artist',
#       'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 231360,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG11601003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4h90qkbnW1Qq6pBhoPvwko'},
#     'href': 'https://api.spotify.com/v1/tracks/4h90qkbnW1Qq6pBhoPvwko',
#     'id': '4h90qkbnW1Qq6pBhoPvwko',
#     'is_local': False,
#     'name': 'Sidewalks',
#     'popularity': 69,
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:4h90qkbnW1Qq6pBhoPvwko'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0P3oVJBFOv3TDXlYRhGL7s'},
#      'href': 'https://api.spotify.com/v1/albums/0P3oVJBFOv3TDXlYRhGL7s',
#      'id': '0P3oVJBFOv3TDXlYRhGL7s',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737fcead687e99583072cc217b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027fcead687e99583072cc217b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517fcead687e99583072cc217b',
#        'width': 64}],
#      'name': 'Beauty Behind The Madness',
#      'release_date': '2015-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0P3oVJBFOv3TDXlYRhGL7s'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 334333,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG11500917'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1mhVXWduD8ReDwusfaHNwU'},
#     'href': 'https://api.spotify.com/v1/tracks/1mhVXWduD8ReDwusfaHNwU',
#     'id': '1mhVXWduD8ReDwusfaHNwU',
#     'is_local': False,
#     'name': 'Tell Your Friends',
#     'popularity': 68,
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1mhVXWduD8ReDwusfaHNwU'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AE',
#       'AU',
#       'BH',
#       'BY',
#       'CA',
#       'DZ',
#       'EG',
#       'GB',
#       'ID',
#       'IE',
#       'IN',
#       'JO',
#       'KW',
#       'KZ',
#       'LB',
#       'MA',
#       'MY',
#       'OM',
#       'PS',
#       'QA',
#       'RU',
#       'SA',
#       'TN',
#       'TR',
#       'UA',
#       'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4AdZV63ycxFLF6Hcol0QnB'},
#      'href': 'https://api.spotify.com/v1/albums/4AdZV63ycxFLF6Hcol0QnB',
#      'id': '4AdZV63ycxFLF6Hcol0QnB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a048415db06a5b6fa7ec4e1a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a048415db06a5b6fa7ec4e1a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a048415db06a5b6fa7ec4e1a',
#        'width': 64}],
#      'name': 'Starboy',
#      'release_date': '2016-11-24',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:4AdZV63ycxFLF6Hcol0QnB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AE',
#      'AU',
#      'BH',
#      'BY',
#      'CA',
#      'DZ',
#      'EG',
#      'GB',
#      'ID',
#      'IE',
#      'IN',
#      'JO',
#      'KW',
#      'KZ',
#      'LB',
#      'MA',
#      'MY',
#      'OM',
#      'PS',
#      'QA',
#      'RU',
#      'SA',
#      'TN',
#      'TR',
#      'UA',
#      'US'],
#     'disc_number': 1,
#     'duration_ms': 260253,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG11600995'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2LBqCSwhJGcFQeTHMVGwy3'},
#     'href': 'https://api.spotify.com/v1/tracks/2LBqCSwhJGcFQeTHMVGwy3',
#     'id': '2LBqCSwhJGcFQeTHMVGwy3',
#     'is_local': False,
#     'name': 'Die For You',
#     'popularity': 66,
#     'preview_url': None,
#     'track_number': 17,
#     'type': 'track',
#     'uri': 'spotify:track:2LBqCSwhJGcFQeTHMVGwy3'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#        'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#        'id': '3TVXtAsR1Inumwj472S9r4',
#        'name': 'Drake',
#        'type': 'artist',
#        'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6X1x82kppWZmDzlXXK3y3q'},
#      'href': 'https://api.spotify.com/v1/albums/6X1x82kppWZmDzlXXK3y3q',
#      'id': '6X1x82kppWZmDzlXXK3y3q',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c7ea04a9b455e3f68ef82550',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c7ea04a9b455e3f68ef82550',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c7ea04a9b455e3f68ef82550',
#        'width': 64}],
#      'name': 'Take Care (Deluxe)',
#      'release_date': '2011-11-15',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:6X1x82kppWZmDzlXXK3y3q'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 208813,
#     'explicit': True,
#     'external_ids': {'isrc': 'USCM51100546'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0V4l4GQhgnWQGtCWpvA7va'},
#     'href': 'https://api.spotify.com/v1/tracks/0V4l4GQhgnWQGtCWpvA7va',
#     'id': '0V4l4GQhgnWQGtCWpvA7va',
#     'is_local': False,
#     'name': 'Crew Love',
#     'popularity': 69,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0V4l4GQhgnWQGtCWpvA7va'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=The+Weeknd&type=track&offset=50&limit=50',
#   'offset': 0,
#   'previous': None,
#   'total': 1540}}

# %% [markdown]
# ## documentation - and useful links
#
# developer app
# https://developer.spotify.com/documentation/general/guides/app-settings/
#
# spotipy documentation
# https://spotipy.readthedocs.io/en/2.16.1/
#
# examples of usage of spotipy including functions
# https://github.com/plamere/spotipy/tree/master/examples
#
# spotify development space with docs
# https://developer.spotify.com/
# - the documentation is fully searchable and has neat try it feature (with temporary token), explains the input parameters, clarifies what your query looks like underneath and lists all the key pairs and data in the output with definitions
#
# AND you can have the spotify web player open https://open.spotify.com/

# %% [markdown]
# a) You can start with exploring the results of your query

# %%
#we know that JSON objects are written in key/value pairs.
# so what are the keys of this data set? 
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
#what is inside the track key? ie what can I navigate with?
results["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
#remember the href ? - thats your query- 
#lets look at what we have searched using the wrapper
results["tracks"]["href"]
# Out:
# 'https://api.spotify.com/v1/search?query=The+Weeknd&type=track&offset=0&limit=50'

# %%
#in tracks - we can get the json on the tracks (its still hard to read)
results["tracks"]["items"]
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#    'href': 'https://api.spotify.com/v1/albums/4yP0hdKOZPNshxUOjY0cZj',
#    'id': '4yP0hdKOZPNshxUOjY0cZj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738863bc11d2aa12b54f5aeb36',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028863bc11d2aa12b54f5aeb36',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518863bc11d2aa12b54f5aeb36',
#      'width': 64}],
#    'name': 'After Hours',
#    'release_date': '2020-03-20',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:4yP0hdKOZPNshxUOjY0cZj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 200040,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG11904206'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b'},
#   'href': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b',
#   'id': '0VjIjW4GlUZAMYd2vXMi3b',
#   'is_local': False,
#   'name': 'Blinding Lights',
#   'popularity': 96,
#   'preview_url': None,
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:0VjIjW4GlUZAMYd2vXMi3b'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1r4hJ1h58CWwUQe3MxPuau'},
#      'href': 'https://api.spotify.com/v1/artists/1r4hJ1h58CWwUQe3MxPuau',
#      'id': '1r4hJ1h58CWwUQe3MxPuau',
#      'name': 'Maluma',
#      'type': 'artist',
#      'uri': 'spotify:artist:1r4hJ1h58CWwUQe3MxPuau'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1Ag9EPbzibwzz0S0WpgX3v'},
#    'href': 'https://api.spotify.com/v1/albums/1Ag9EPbzibwzz0S0WpgX3v',
#    'id': '1Ag9EPbzibwzz0S0WpgX3v',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273be768155351bbd7d4c19ab13',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02be768155351bbd7d4c19ab13',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851be768155351bbd7d4c19ab13',
#      'width': 64}],
#    'name': 'Hawái (Remix)',
#    'release_date': '2020-11-05',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:1Ag9EPbzibwzz0S0WpgX3v'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1r4hJ1h58CWwUQe3MxPuau'},
#     'href': 'https://api.spotify.com/v1/artists/1r4hJ1h58CWwUQe3MxPuau',
#     'id': '1r4hJ1h58CWwUQe3MxPuau',
#     'name': 'Maluma',
#     'type': 'artist',
#     'uri': 'spotify:artist:1r4hJ1h58CWwUQe3MxPuau'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 200481,
#   'explicit': False,
#   'external_ids': {'isrc': 'USSD12000526'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0GzuHFG4Ql6DoyxFRnIk3F'},
#   'href': 'https://api.spotify.com/v1/tracks/0GzuHFG4Ql6DoyxFRnIk3F',
#   'id': '0GzuHFG4Ql6DoyxFRnIk3F',
#   'is_local': False,
#   'name': 'Hawái - Remix',
#   'popularity': 90,
#   'preview_url': 'https://p.scdn.co/mp3-preview/387b491a7a8a2200379386e98f2f4a95506bb107?cid=c39fbc66489441ce809290f1c586c0db',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0GzuHFG4Ql6DoyxFRnIk3F'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#      'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#      'id': '66CXWjxzNUsdJxJ2JdwvnR',
#      'name': 'Ariana Grande',
#      'type': 'artist',
#      'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3euz4vS7ezKGnNSwgyvKcd'},
#    'href': 'https://api.spotify.com/v1/albums/3euz4vS7ezKGnNSwgyvKcd',
#    'id': '3euz4vS7ezKGnNSwgyvKcd',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735ef878a782c987d38d82b605',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025ef878a782c987d38d82b605',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515ef878a782c987d38d82b605',
#      'width': 64}],
#    'name': 'Positions',
#    'release_date': '2020-10-30',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:3euz4vS7ezKGnNSwgyvKcd'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#     'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#     'id': '66CXWjxzNUsdJxJ2JdwvnR',
#     'name': 'Ariana Grande',
#     'type': 'artist',
#     'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 239949,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM72020429'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7E1jVNoWuemqUryI4FxsVD'},
#   'href': 'https://api.spotify.com/v1/tracks/7E1jVNoWuemqUryI4FxsVD',
#   'id': '7E1jVNoWuemqUryI4FxsVD',
#   'is_local': False,
#   'name': 'off the table (with The Weeknd)',
#   'popularity': 84,
#   'preview_url': None,
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:7E1jVNoWuemqUryI4FxsVD'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MCBfE4596Uoi2O4DtmEMz'},
#      'href': 'https://api.spotify.com/v1/artists/4MCBfE4596Uoi2O4DtmEMz',
#      'id': '4MCBfE4596Uoi2O4DtmEMz',
#      'name': 'Juice WRLD',
#      'type': 'artist',
#      'uri': 'spotify:artist:4MCBfE4596Uoi2O4DtmEMz'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6n9DKpOxwifT5hOXtgLZSL'},
#    'href': 'https://api.spotify.com/v1/albums/6n9DKpOxwifT5hOXtgLZSL',
#    'id': '6n9DKpOxwifT5hOXtgLZSL',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2733e0698e4ae5ffb82a005aeeb',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e023e0698e4ae5ffb82a005aeeb',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048513e0698e4ae5ffb82a005aeeb',
#      'width': 64}],
#    'name': 'Legends Never Die',
#    'release_date': '2020-07-10',
#    'release_date_precision': 'day',
#    'total_tracks': 22,
#    'type': 'album',
#    'uri': 'spotify:album:6n9DKpOxwifT5hOXtgLZSL'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MCBfE4596Uoi2O4DtmEMz'},
#     'href': 'https://api.spotify.com/v1/artists/4MCBfE4596Uoi2O4DtmEMz',
#     'id': '4MCBfE4596Uoi2O4DtmEMz',
#     'name': 'Juice WRLD',
#     'type': 'artist',
#     'uri': 'spotify:artist:4MCBfE4596Uoi2O4DtmEMz'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 196180,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG12002597'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6wQlQrTY5mVS8EGaFZVwVF'},
#   'href': 'https://api.spotify.com/v1/tracks/6wQlQrTY5mVS8EGaFZVwVF',
#   'id': '6wQlQrTY5mVS8EGaFZVwVF',
#   'is_local': False,
#   'name': 'Smile (with The Weeknd)',
#   'popularity': 83,
#   'preview_url': None,
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:6wQlQrTY5mVS8EGaFZVwVF'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0P3oVJBFOv3TDXlYRhGL7s'},
#    'href': 'https://api.spotify.com/v1/albums/0P3oVJBFOv3TDXlYRhGL7s',
#    'id': '0P3oVJBFOv3TDXlYRhGL7s',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2737fcead687e99583072cc217b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e027fcead687e99583072cc217b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048517fcead687e99583072cc217b',
#      'width': 64}],
#    'name': 'Beauty Behind The Madness',
#    'release_date': '2015-08-28',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:0P3oVJBFOv3TDXlYRhGL7s'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 242253,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG11500737'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7fBv7CLKzipRk6EC6TWHOB'},
#   'href': 'https://api.spotify.com/v1/tracks/7fBv7CLKzipRk6EC6TWHOB',
#   'id': '7fBv7CLKzipRk6EC6TWHOB',
#   'is_local': False,
#   'name': 'The Hills',
#   'popularity': 83,
#   'preview_url': None,
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:7fBv7CLKzipRk6EC6TWHOB'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#    'href': 'https://api.spotify.com/v1/albums/2ODvWsOgouMbaA5xf0RkJe',
#    'id': '2ODvWsOgouMbaA5xf0RkJe',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734718e2b124f79258be7bc452',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024718e2b124f79258be7bc452',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514718e2b124f79258be7bc452',
#      'width': 64}],
#    'name': 'Starboy',
#    'release_date': '2016-11-25',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:2ODvWsOgouMbaA5xf0RkJe'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#     'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#     'id': '4tZwfgrHOc3mvqYlEYSvVi',
#     'name': 'Daft Punk',
#     'type': 'artist',
#     'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 230453,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG11600976'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7MXVkk9YMctZqd1Srtv4MB'},
#   'href': 'https://api.spotify.com/v1/tracks/7MXVkk9YMctZqd1Srtv4MB',
#   'id': '7MXVkk9YMctZqd1Srtv4MB',
#   'is_local': False,
#   'name': 'Starboy',
#   'popularity': 83,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:7MXVkk9YMctZqd1Srtv4MB'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#    'href': 'https://api.spotify.com/v1/albums/4yP0hdKOZPNshxUOjY0cZj',
#    'id': '4yP0hdKOZPNshxUOjY0cZj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738863bc11d2aa12b54f5aeb36',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028863bc11d2aa12b54f5aeb36',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518863bc11d2aa12b54f5aeb36',
#      'width': 64}],
#    'name': 'After Hours',
#    'release_date': '2020-03-20',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:4yP0hdKOZPNshxUOjY0cZj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 198266,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG11904007'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6bnF93Rx87YqUBLSgjiMU8'},
#   'href': 'https://api.spotify.com/v1/tracks/6bnF93Rx87YqUBLSgjiMU8',
#   'id': '6bnF93Rx87YqUBLSgjiMU8',
#   'is_local': False,
#   'name': 'Heartless',
#   'popularity': 80,
#   'preview_url': None,
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:6bnF93Rx87YqUBLSgjiMU8'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#    'href': 'https://api.spotify.com/v1/albums/4yP0hdKOZPNshxUOjY0cZj',
#    'id': '4yP0hdKOZPNshxUOjY0cZj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738863bc11d2aa12b54f5aeb36',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028863bc11d2aa12b54f5aeb36',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518863bc11d2aa12b54f5aeb36',
#      'width': 64}],
#    'name': 'After Hours',
#    'release_date': '2020-03-20',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:4yP0hdKOZPNshxUOjY0cZj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 237520,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG12000657'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7szuecWAPwGoV1e5vGu8tl'},
#   'href': 'https://api.spotify.com/v1/tracks/7szuecWAPwGoV1e5vGu8tl',
#   'id': '7szuecWAPwGoV1e5vGu8tl',
#   'is_local': False,
#   'name': 'In Your Eyes',
#   'popularity': 85,
#   'preview_url': None,
#   'track_number': 10,
#   'type': 'track',
#   'uri': 'spotify:track:7szuecWAPwGoV1e5vGu8tl'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4qZBW3f2Q8y0k1A84d4iAO'},
#    'href': 'https://api.spotify.com/v1/albums/4qZBW3f2Q8y0k1A84d4iAO',
#    'id': '4qZBW3f2Q8y0k1A84d4iAO',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2731f6a2a40bb692936879db730',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e021f6a2a40bb692936879db730',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048511f6a2a40bb692936879db730',
#      'width': 64}],
#    'name': 'My Dear Melancholy,',
#    'release_date': '2018-03-30',
#    'release_date_precision': 'day',
#    'total_tracks': 7,
#    'type': 'album',
#    'uri': 'spotify:album:4qZBW3f2Q8y0k1A84d4iAO'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 228373,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG11800560'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/09mEdoA6zrmBPgTEN5qXmN'},
#   'href': 'https://api.spotify.com/v1/tracks/09mEdoA6zrmBPgTEN5qXmN',
#   'id': '09mEdoA6zrmBPgTEN5qXmN',
#   'is_local': False,
#   'name': 'Call Out My Name',
#   'popularity': 81,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:09mEdoA6zrmBPgTEN5qXmN'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7c0XG5cIJTrrAgEC3ULPiq'},
#      'href': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq',
#      'id': '7c0XG5cIJTrrAgEC3ULPiq',
#      'name': 'Ty Dolla $ign',
#      'type': 'artist',
#      'uri': 'spotify:artist:7c0XG5cIJTrrAgEC3ULPiq'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3SHx7bBQFI4J8QRr6D5cOK'},
#    'href': 'https://api.spotify.com/v1/albums/3SHx7bBQFI4J8QRr6D5cOK',
#    'id': '3SHx7bBQFI4J8QRr6D5cOK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2731c04efd2804b16cf689de7f0',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e021c04efd2804b16cf689de7f0',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048511c04efd2804b16cf689de7f0',
#      'width': 64}],
#    'name': 'Or Nah (feat. The Weeknd, Wiz Khalifa & DJ Mustard) [Remix]',
#    'release_date': '2014-06-10',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3SHx7bBQFI4J8QRr6D5cOK'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7c0XG5cIJTrrAgEC3ULPiq'},
#     'href': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq',
#     'id': '7c0XG5cIJTrrAgEC3ULPiq',
#     'name': 'Ty Dolla $ign',
#     'type': 'artist',
#     'uri': 'spotify:artist:7c0XG5cIJTrrAgEC3ULPiq'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/137W8MRPWKqSmrBGDBFSop'},
#     'href': 'https://api.spotify.com/v1/artists/137W8MRPWKqSmrBGDBFSop',
#     'id': '137W8MRPWKqSmrBGDBFSop',
#     'name': 'Wiz Khalifa',
#     'type': 'artist',
#     'uri': 'spotify:artist:137W8MRPWKqSmrBGDBFSop'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0YinUQ50QDB7ZxSCLyQ40k'},
#     'href': 'https://api.spotify.com/v1/artists/0YinUQ50QDB7ZxSCLyQ40k',
#     'id': '0YinUQ50QDB7ZxSCLyQ40k',
#     'name': 'Mustard',
#     'type': 'artist',
#     'uri': 'spotify:artist:0YinUQ50QDB7ZxSCLyQ40k'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 242983,
#   'explicit': True,
#   'external_ids': {'isrc': 'USAT21401391'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7t2bFihaDvhIrd2gn2CWJO'},
#   'href': 'https://api.spotify.com/v1/tracks/7t2bFihaDvhIrd2gn2CWJO',
#   'id': '7t2bFihaDvhIrd2gn2CWJO',
#   'is_local': False,
#   'name': 'Or Nah (feat. The Weeknd, Wiz Khalifa & DJ Mustard) - Remix',
#   'popularity': 79,
#   'preview_url': 'https://p.scdn.co/mp3-preview/70f126c139847335bc03c756c55b80c99892268e?cid=c39fbc66489441ce809290f1c586c0db',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:7t2bFihaDvhIrd2gn2CWJO'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#    'href': 'https://api.spotify.com/v1/albums/4yP0hdKOZPNshxUOjY0cZj',
#    'id': '4yP0hdKOZPNshxUOjY0cZj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738863bc11d2aa12b54f5aeb36',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028863bc11d2aa12b54f5aeb36',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518863bc11d2aa12b54f5aeb36',
#      'width': 64}],
#    'name': 'After Hours',
#    'release_date': '2020-03-20',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:4yP0hdKOZPNshxUOjY0cZj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 361026,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG12000586'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2p8IUWQDrpjuFltbdgLOag'},
#   'href': 'https://api.spotify.com/v1/tracks/2p8IUWQDrpjuFltbdgLOag',
#   'id': '2p8IUWQDrpjuFltbdgLOag',
#   'is_local': False,
#   'name': 'After Hours',
#   'popularity': 79,
#   'preview_url': None,
#   'track_number': 13,
#   'type': 'track',
#   'uri': 'spotify:track:2p8IUWQDrpjuFltbdgLOag'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CajNmpbOovFoOoasH2HaY'},
#      'href': 'https://api.spotify.com/v1/artists/7CajNmpbOovFoOoasH2HaY',
#      'id': '7CajNmpbOovFoOoasH2HaY',
#      'name': 'Calvin Harris',
#      'type': 'artist',
#      'uri': 'spotify:artist:7CajNmpbOovFoOoasH2HaY'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3GPiefSRSOxqTrgKJIB7RL'},
#    'href': 'https://api.spotify.com/v1/albums/3GPiefSRSOxqTrgKJIB7RL',
#    'id': '3GPiefSRSOxqTrgKJIB7RL',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e5e19455ff5f76c58048bea8',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e5e19455ff5f76c58048bea8',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e5e19455ff5f76c58048bea8',
#      'width': 64}],
#    'name': 'Over Now (with The Weeknd)',
#    'release_date': '2020-08-28',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3GPiefSRSOxqTrgKJIB7RL'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CajNmpbOovFoOoasH2HaY'},
#     'href': 'https://api.spotify.com/v1/artists/7CajNmpbOovFoOoasH2HaY',
#     'id': '7CajNmpbOovFoOoasH2HaY',
#     'name': 'Calvin Harris',
#     'type': 'artist',
#     'uri': 'spotify:artist:7CajNmpbOovFoOoasH2HaY'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 210795,
#   'explicit': True,
#   'external_ids': {'isrc': 'GBARL2000986'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/58AGoOGbwsQMhBbH0eFLRR'},
#   'href': 'https://api.spotify.com/v1/tracks/58AGoOGbwsQMhBbH0eFLRR',
#   'id': '58AGoOGbwsQMhBbH0eFLRR',
#   'is_local': False,
#   'name': 'Over Now (with The Weeknd)',
#   'popularity': 80,
#   'preview_url': 'https://p.scdn.co/mp3-preview/acb8090a47526a5ba6b9d5baec8497d2eecaaf35?cid=c39fbc66489441ce809290f1c586c0db',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:58AGoOGbwsQMhBbH0eFLRR'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
# ...
#      'width': 64}],
#    'name': 'After Hours (Deluxe)',
#    'release_date': '2020-04-03',
#    'release_date_precision': 'day',
#    'total_tracks': 17,
#    'type': 'album',
#    'uri': 'spotify:album:6YlDIxqEjvY63ffH6AwCjd'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 144539,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG11904289'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/38uNCW1do0LKfMIt4MDkPo'},
#   'href': 'https://api.spotify.com/v1/tracks/38uNCW1do0LKfMIt4MDkPo',
#   'id': '38uNCW1do0LKfMIt4MDkPo',
#   'is_local': False,
#   'name': 'Missed You - Bonus Track',
#   'popularity': 71,
#   'preview_url': None,
#   'track_number': 16,
#   'type': 'track',
#   'uri': 'spotify:track:38uNCW1do0LKfMIt4MDkPo'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#    'href': 'https://api.spotify.com/v1/albums/2ODvWsOgouMbaA5xf0RkJe',
#    'id': '2ODvWsOgouMbaA5xf0RkJe',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734718e2b124f79258be7bc452',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024718e2b124f79258be7bc452',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514718e2b124f79258be7bc452',
#      'width': 64}],
#    'name': 'Starboy',
#    'release_date': '2016-11-25',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:2ODvWsOgouMbaA5xf0RkJe'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#     'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#     'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#     'name': 'Kendrick Lamar',
#     'type': 'artist',
#     'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 231360,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG11601003'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4h90qkbnW1Qq6pBhoPvwko'},
#   'href': 'https://api.spotify.com/v1/tracks/4h90qkbnW1Qq6pBhoPvwko',
#   'id': '4h90qkbnW1Qq6pBhoPvwko',
#   'is_local': False,
#   'name': 'Sidewalks',
#   'popularity': 69,
#   'preview_url': None,
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:4h90qkbnW1Qq6pBhoPvwko'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0P3oVJBFOv3TDXlYRhGL7s'},
#    'href': 'https://api.spotify.com/v1/albums/0P3oVJBFOv3TDXlYRhGL7s',
#    'id': '0P3oVJBFOv3TDXlYRhGL7s',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2737fcead687e99583072cc217b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e027fcead687e99583072cc217b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048517fcead687e99583072cc217b',
#      'width': 64}],
#    'name': 'Beauty Behind The Madness',
#    'release_date': '2015-08-28',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:0P3oVJBFOv3TDXlYRhGL7s'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 334333,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG11500917'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1mhVXWduD8ReDwusfaHNwU'},
#   'href': 'https://api.spotify.com/v1/tracks/1mhVXWduD8ReDwusfaHNwU',
#   'id': '1mhVXWduD8ReDwusfaHNwU',
#   'is_local': False,
#   'name': 'Tell Your Friends',
#   'popularity': 68,
#   'preview_url': None,
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:1mhVXWduD8ReDwusfaHNwU'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AE',
#     'AU',
#     'BH',
#     'BY',
#     'CA',
#     'DZ',
#     'EG',
#     'GB',
#     'ID',
#     'IE',
#     'IN',
#     'JO',
#     'KW',
#     'KZ',
#     'LB',
#     'MA',
#     'MY',
#     'OM',
#     'PS',
#     'QA',
#     'RU',
#     'SA',
#     'TN',
#     'TR',
#     'UA',
#     'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4AdZV63ycxFLF6Hcol0QnB'},
#    'href': 'https://api.spotify.com/v1/albums/4AdZV63ycxFLF6Hcol0QnB',
#    'id': '4AdZV63ycxFLF6Hcol0QnB',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a048415db06a5b6fa7ec4e1a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a048415db06a5b6fa7ec4e1a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a048415db06a5b6fa7ec4e1a',
#      'width': 64}],
#    'name': 'Starboy',
#    'release_date': '2016-11-24',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:4AdZV63ycxFLF6Hcol0QnB'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AE',
#    'AU',
#    'BH',
#    'BY',
#    'CA',
#    'DZ',
#    'EG',
#    'GB',
#    'ID',
#    'IE',
#    'IN',
#    'JO',
#    'KW',
#    'KZ',
#    'LB',
#    'MA',
#    'MY',
#    'OM',
#    'PS',
#    'QA',
#    'RU',
#    'SA',
#    'TN',
#    'TR',
#    'UA',
#    'US'],
#   'disc_number': 1,
#   'duration_ms': 260253,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG11600995'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2LBqCSwhJGcFQeTHMVGwy3'},
#   'href': 'https://api.spotify.com/v1/tracks/2LBqCSwhJGcFQeTHMVGwy3',
#   'id': '2LBqCSwhJGcFQeTHMVGwy3',
#   'is_local': False,
#   'name': 'Die For You',
#   'popularity': 66,
#   'preview_url': None,
#   'track_number': 17,
#   'type': 'track',
#   'uri': 'spotify:track:2LBqCSwhJGcFQeTHMVGwy3'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6X1x82kppWZmDzlXXK3y3q'},
#    'href': 'https://api.spotify.com/v1/albums/6X1x82kppWZmDzlXXK3y3q',
#    'id': '6X1x82kppWZmDzlXXK3y3q',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c7ea04a9b455e3f68ef82550',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c7ea04a9b455e3f68ef82550',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c7ea04a9b455e3f68ef82550',
#      'width': 64}],
#    'name': 'Take Care (Deluxe)',
#    'release_date': '2011-11-15',
#    'release_date_precision': 'day',
#    'total_tracks': 19,
#    'type': 'album',
#    'uri': 'spotify:album:6X1x82kppWZmDzlXXK3y3q'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#     'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#     'id': '3TVXtAsR1Inumwj472S9r4',
#     'name': 'Drake',
#     'type': 'artist',
#     'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 208813,
#   'explicit': True,
#   'external_ids': {'isrc': 'USCM51100546'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0V4l4GQhgnWQGtCWpvA7va'},
#   'href': 'https://api.spotify.com/v1/tracks/0V4l4GQhgnWQGtCWpvA7va',
#   'id': '0V4l4GQhgnWQGtCWpvA7va',
#   'is_local': False,
#   'name': 'Crew Love',
#   'popularity': 69,
#   'preview_url': None,
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:0V4l4GQhgnWQGtCWpvA7va'}]

# %%
#we did run a limit of 50 in our query - but can easily go to next 50
results["tracks"]["next"]

# %%
results

# %%
#if we want to go back to the prev 50 - shortcut
results["tracks"]["previous"]

# %%
#total number of matches from the original query string
results["tracks"]["total"]
# Out:
# 1540

# %% [markdown]
# b) next, we can drill in to one row of your results - ie one track

# %%
#in my example I am using the index value 5, ie the 6th member returned 
results["tracks"]["items"][5].keys() #items (actual tracks)
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
#inside the json string we have information about the album for the selected track
results["tracks"]["items"][5]["album"]
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#    'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#    'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#    'name': 'The Weeknd',
#    'type': 'artist',
#    'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#  'available_markets': ['AD',
#   'AE',
#   'AL',
#   'AR',
#   'AT',
#   'AU',
#   'BA',
#   'BE',
#   'BG',
#   'BH',
#   'BO',
#   'BR',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HR',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JO',
#   'JP',
#   'KW',
#   'KZ',
#   'LB',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MK',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'SA',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SV',
#   'TH',
#   'TN',
#   'TR',
#   'TW',
#   'UA',
#   'US',
#   'UY',
#   'VN',
#   'XK',
#   'ZA'],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#  'href': 'https://api.spotify.com/v1/albums/2ODvWsOgouMbaA5xf0RkJe',
#  'id': '2ODvWsOgouMbaA5xf0RkJe',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b2734718e2b124f79258be7bc452',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e024718e2b124f79258be7bc452',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d000048514718e2b124f79258be7bc452',
#    'width': 64}],
#  'name': 'Starboy',
#  'release_date': '2016-11-25',
#  'release_date_precision': 'day',
#  'total_tracks': 18,
#  'type': 'album',
#  'uri': 'spotify:album:2ODvWsOgouMbaA5xf0RkJe'}

# %%
#and the artist
results["tracks"]["items"][5]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#   'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#   'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'name': 'The Weeknd',
#   'type': 'artist',
#   'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#   'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#   'id': '4tZwfgrHOc3mvqYlEYSvVi',
#   'name': 'Daft Punk',
#   'type': 'artist',
#   'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}]

# %%
#the name of the song 
results["tracks"]["items"][5]["name"]
# Out:
# 'Starboy'

# %%
# how popular is it on spotify?
results["tracks"]["items"][1]["popularity"]
# Out:
# 90

# %% [markdown]
# What is a popularity score?
#
# The score is received from the Spotify API. The value will be between 0 and 100, with 100 being the most popular.
#
# The popularity is calculated by algorithm and is based, in the most part, on the total number of plays the track has had and how recent those plays are.
#
# Generally speaking, songs that are being played a lot now will have a higher popularity than songs that were played a lot in the past. Duplicate tracks (e.g. the same track from a single and an album) are rated independently. Artist and album popularity is derived mathematically from track popularity. Note that the popularity value may lag actual popularity by a few days: the value is not updated in real time.

# %%
# to get the uri of a song
results["tracks"]["items"][5]["uri"]
# Out:
# 'spotify:track:7MXVkk9YMctZqd1Srtv4MB'

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri" or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.
#
# We'll use the `uri` in this code-along, but feel free to use whatever you think fits best your needs.

# %%
#what can we pull out of the api for this track ? 
results["tracks"]["items"][5].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %% [markdown]
# Artist analysis - this is more just for fun than for the project

# %%
#get all albums for your favourite artist
#- using spotify web browser to find uri of chosen artist 

artist = sp.artist("https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d")

albums = []
results = sp.artist_albums(artist['id'], album_type='album')
albums.extend(results['items'])
while results['next']:
    results = sp.next(results)
    albums.extend(results['items'])

albums.sort(key=lambda album:album['name'].lower())
for album in albums:
    name = album['name']
    print((' ' + name))

print(len(albums))

# %%
#how to query more than one artist at once
artists = ["Katy Perry", "Duffy", "Adele"]

# %%
my_3_artists = [sp.search(q=artist, limit=50) for artist in artists]
my_3_artists
# Out:
# [{'tracks': {'href': 'https://api.spotify.com/v1/search?query=Katy+Perry&type=track&offset=0&limit=50',
#    'items': [{'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#         'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#         'id': '6jJ0s89eD6GaHleKKya26X',
#         'name': 'Katy Perry',
#         'type': 'artist',
#         'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2m5J1DUH7hJpPSOromIqpN'},
#       'href': 'https://api.spotify.com/v1/albums/2m5J1DUH7hJpPSOromIqpN',
#       'id': '2m5J1DUH7hJpPSOromIqpN',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2738df6751bad8ab6b5c928dba3',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e028df6751bad8ab6b5c928dba3',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048518df6751bad8ab6b5c928dba3',
#         'width': 64}],
#       'name': 'Daisies',
#       'release_date': '2020-05-15',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:2m5J1DUH7hJpPSOromIqpN'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#        'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#        'id': '6jJ0s89eD6GaHleKKya26X',
#        'name': 'Katy Perry',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 173123,
#      'explicit': False,
#      'external_ids': {'isrc': 'USUM72007214'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4uqh9bualXNHXXwO2wPorc'},
#      'href': 'https://api.spotify.com/v1/tracks/4uqh9bualXNHXXwO2wPorc',
#      'id': '4uqh9bualXNHXXwO2wPorc',
#      'is_local': False,
#      'name': 'Daisies',
#      'popularity': 79,
#      'preview_url': None,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:4uqh9bualXNHXXwO2wPorc'},
#     {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#         'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#         'id': '6jJ0s89eD6GaHleKKya26X',
#         'name': 'Katy Perry',
#         'type': 'artist',
#         'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5IxObv8TvRsYE6DGKnbrXn'},
#       'href': 'https://api.spotify.com/v1/albums/5IxObv8TvRsYE6DGKnbrXn',
#       'id': '5IxObv8TvRsYE6DGKnbrXn',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273b24ac6c9632013d83ee90876',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02b24ac6c9632013d83ee90876',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851b24ac6c9632013d83ee90876',
#         'width': 64}],
#       'name': 'Cozy Little Christmas',
#       'release_date': '2018-11-15',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:5IxObv8TvRsYE6DGKnbrXn'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#        'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#        'id': '6jJ0s89eD6GaHleKKya26X',
#        'name': 'Katy Perry',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 182520,
#      'explicit': False,
#      'external_ids': {'isrc': 'USUM71819190'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/02FaKXXL7KUtRc7K0k54tL'},
#      'href': 'https://api.spotify.com/v1/tracks/02FaKXXL7KUtRc7K0k54tL',
#      'id': '02FaKXXL7KUtRc7K0k54tL',
#      'is_local': False,
#      'name': 'Cozy Little Christmas',
#      'popularity': 76,
#      'preview_url': None,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:02FaKXXL7KUtRc7K0k54tL'},
#     {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#         'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#         'id': '6jJ0s89eD6GaHleKKya26X',
#         'name': 'Katy Perry',
#         'type': 'artist',
#         'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/3KjXg0MDej2pG9fv6I22lT'},
#       'href': 'https://api.spotify.com/v1/albums/3KjXg0MDej2pG9fv6I22lT',
#       'id': '3KjXg0MDej2pG9fv6I22lT',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2739bea3b79b95f86d1b66ac960',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e029bea3b79b95f86d1b66ac960',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048519bea3b79b95f86d1b66ac960',
#         'width': 64}],
#       'name': 'Never Really Over',
#       'release_date': '2019-05-31',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:3KjXg0MDej2pG9fv6I22lT'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#        'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#        'id': '6jJ0s89eD6GaHleKKya26X',
#        'name': 'Katy Perry',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 223523,
#      'explicit': False,
#      'external_ids': {'isrc': 'USUM71901873'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5PYQUBXc7NYeI1obMKSJK0'},
#      'href': 'https://api.spotify.com/v1/tracks/5PYQUBXc7NYeI1obMKSJK0',
#      'id': '5PYQUBXc7NYeI1obMKSJK0',
#      'is_local': False,
#      'name': 'Never Really Over',
#      'popularity': 78,
#      'preview_url': None,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:5PYQUBXc7NYeI1obMKSJK0'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#         'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#         'id': '6jJ0s89eD6GaHleKKya26X',
#         'name': 'Katy Perry',
#         'type': 'artist',
#         'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5MQBzs5YlZlE28mD9yUItn'},
#       'href': 'https://api.spotify.com/v1/albums/5MQBzs5YlZlE28mD9yUItn',
#       'id': '5MQBzs5YlZlE28mD9yUItn',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27347f930accd8ac01686401fa2',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0247f930accd8ac01686401fa2',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485147f930accd8ac01686401fa2',
#         'width': 64}],
#       'name': 'PRISM (Deluxe)',
#       'release_date': '2013-10-18',
#       'release_date_precision': 'day',
#       'total_tracks': 16,
#       'type': 'album',
#       'uri': 'spotify:album:5MQBzs5YlZlE28mD9yUItn'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#        'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#        'id': '6jJ0s89eD6GaHleKKya26X',
#        'name': 'Katy Perry',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5gCRApTajqwbnHHPbr2Fpi'},
#        'href': 'https://api.spotify.com/v1/artists/5gCRApTajqwbnHHPbr2Fpi',
#        'id': '5gCRApTajqwbnHHPbr2Fpi',
#        'name': 'Juicy J',
#        'type': 'artist',
#        'uri': 'spotify:artist:5gCRApTajqwbnHHPbr2Fpi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 215672,
#      'explicit': False,
#      'external_ids': {'isrc': 'USUM71311296'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5jrdCoLpJSvHHorevXBATy'},
#      'href': 'https://api.spotify.com/v1/tracks/5jrdCoLpJSvHHorevXBATy',
#      'id': '5jrdCoLpJSvHHorevXBATy',
#      'is_local': False,
#      'name': 'Dark Horse',
#      'popularity': 75,
#      'preview_url': None,
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:5jrdCoLpJSvHHorevXBATy'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#         'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#         'id': '6jJ0s89eD6GaHleKKya26X',
#         'name': 'Katy Perry',
#         'type': 'artist',
#         'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5BvgP623rtvlc0HDcpzquz'},
#       'href': 'https://api.spotify.com/v1/albums/5BvgP623rtvlc0HDcpzquz',
#       'id': '5BvgP623rtvlc0HDcpzquz',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273937af329667311f4b2831616',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02937af329667311f4b2831616',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851937af329667311f4b2831616',
#         'width': 64}],
#       'name': 'Katy Perry - Teenage Dream: The Complete Confection',
#       'release_date': '2012-03-12',
#       'release_date_precision': 'day',
#       'total_tracks': 19,
#       'type': 'album',
#       'uri': 'spotify:album:5BvgP623rtvlc0HDcpzquz'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#        'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#        'id': '6jJ0s89eD6GaHleKKya26X',
#        'name': 'Katy Perry',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 227333,
#      'explicit': False,
#      'external_ids': {'isrc': 'USCA21001266'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3oL3XRtkP1WVbMxf7dtTdu'},
#      'href': 'https://api.spotify.com/v1/tracks/3oL3XRtkP1WVbMxf7dtTdu',
#      'id': '3oL3XRtkP1WVbMxf7dtTdu',
#      'is_local': False,
#      'name': 'The One That Got Away',
#      'popularity': 74,
#      'preview_url': None,
#      'track_number': 7,
#      'type': 'track',
#      'uri': 'spotify:track:3oL3XRtkP1WVbMxf7dtTdu'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#         'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#         'id': '6jJ0s89eD6GaHleKKya26X',
#         'name': 'Katy Perry',
#         'type': 'artist',
#         'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5MQBzs5YlZlE28mD9yUItn'},
#       'href': 'https://api.spotify.com/v1/albums/5MQBzs5YlZlE28mD9yUItn',
#       'id': '5MQBzs5YlZlE28mD9yUItn',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27347f930accd8ac01686401fa2',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0247f930accd8ac01686401fa2',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485147f930accd8ac01686401fa2',
#         'width': 64}],
#       'name': 'PRISM (Deluxe)',
#       'release_date': '2013-10-18',
#       'release_date_precision': 'day',
#       'total_tracks': 16,
#       'type': 'album',
#       'uri': 'spotify:album:5MQBzs5YlZlE28mD9yUItn'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#        'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#        'id': '6jJ0s89eD6GaHleKKya26X',
#        'name': 'Katy Perry',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 223546,
#      'explicit': False,
#      'external_ids': {'isrc': 'USUM71308669'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6F5c58TMEs1byxUstkzVeM'},
#      'href': 'https://api.spotify.com/v1/tracks/6F5c58TMEs1byxUstkzVeM',
#      'id': '6F5c58TMEs1byxUstkzVeM',
#      'is_local': False,
#      'name': 'Roar',
#      'popularity': 74,
#      'preview_url': None,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:6F5c58TMEs1byxUstkzVeM'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#         'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#         'id': '6jJ0s89eD6GaHleKKya26X',
#         'name': 'Katy Perry',
#         'type': 'artist',
#         'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5BvgP623rtvlc0HDcpzquz'},
#       'href': 'https://api.spotify.com/v1/albums/5BvgP623rtvlc0HDcpzquz',
#       'id': '5BvgP623rtvlc0HDcpzquz',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273937af329667311f4b2831616',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02937af329667311f4b2831616',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851937af329667311f4b2831616',
#         'width': 64}],
#       'name': 'Katy Perry - Teenage Dream: The Complete Confection',
#       'release_date': '2012-03-12',
#       'release_date_precision': 'day',
#       'total_tracks': 19,
#       'type': 'album',
#       'uri': 'spotify:album:5BvgP623rtvlc0HDcpzquz'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#        'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#        'id': '6jJ0s89eD6GaHleKKya26X',
#        'name': 'Katy Perry',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 230746,
#      'explicit': False,
#      'external_ids': {'isrc': 'USCA21001264'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/455AfCsOhhLPRc68sE01D8'},
#      'href': 'https://api.spotify.com/v1/tracks/455AfCsOhhLPRc68sE01D8',
#      'id': '455AfCsOhhLPRc68sE01D8',
#      'is_local': False,
#      'name': 'Last Friday Night (T.G.I.F.)',
#      'popularity': 74,
#      'preview_url': None,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:455AfCsOhhLPRc68sE01D8'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CajNmpbOovFoOoasH2HaY'},
#         'href': 'https://api.spotify.com/v1/artists/7CajNmpbOovFoOoasH2HaY',
#         'id': '7CajNmpbOovFoOoasH2HaY',
#         'name': 'Calvin Harris',
#         'type': 'artist',
#         'uri': 'spotify:artist:7CajNmpbOovFoOoasH2HaY'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/4A0TivfinfALCAMJqqjZIk'},
#         'href': 'https://api.spotify.com/v1/artists/4A0TivfinfALCAMJqqjZIk',
#         'id': '4A0TivfinfALCAMJqqjZIk',
#         'name': 'Funk Wav',
#         'type': 'artist',
#         'uri': 'spotify:artist:4A0TivfinfALCAMJqqjZIk'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2HaqChIDc5go3qxVunBDK0'},
#       'href': 'https://api.spotify.com/v1/albums/2HaqChIDc5go3qxVunBDK0',
#       'id': '2HaqChIDc5go3qxVunBDK0',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2734d3fa5ce7ba599f4fd7803ef',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e024d3fa5ce7ba599f4fd7803ef',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048514d3fa5ce7ba599f4fd7803ef',
#         'width': 64}],
#       'name': 'Funk Wav Bounces Vol.1',
#       'release_date': '2017-06-30',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:2HaqChIDc5go3qxVunBDK0'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CajNmpbOovFoOoasH2HaY'},
#        'href': 'https://api.spotify.com/v1/artists/7CajNmpbOovFoOoasH2HaY',
#        'id': '7CajNmpbOovFoOoasH2HaY',
#        'name': 'Calvin Harris',
#        'type': 'artist',
#        'uri': 'spotify:artist:7CajNmpbOovFoOoasH2HaY'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2RdwBSPQiwcmiDo9kixcl8'},
#        'href': 'https://api.spotify.com/v1/artists/2RdwBSPQiwcmiDo9kixcl8',
#        'id': '2RdwBSPQiwcmiDo9kixcl8',
#        'name': 'Pharrell Williams',
#        'type': 'artist',
#        'uri': 'spotify:artist:2RdwBSPQiwcmiDo9kixcl8'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#        'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#        'id': '6jJ0s89eD6GaHleKKya26X',
#        'name': 'Katy Perry',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0c173mlxpT3dSFRgMO8XPh'},
#        'href': 'https://api.spotify.com/v1/artists/0c173mlxpT3dSFRgMO8XPh',
#        'id': '0c173mlxpT3dSFRgMO8XPh',
#        'name': 'Big Sean',
#        'type': 'artist',
#        'uri': 'spotify:artist:0c173mlxpT3dSFRgMO8XPh'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4A0TivfinfALCAMJqqjZIk'},
#        'href': 'https://api.spotify.com/v1/artists/4A0TivfinfALCAMJqqjZIk',
#        'id': '4A0TivfinfALCAMJqqjZIk',
#        'name': 'Funk Wav',
#        'type': 'artist',
#        'uri': 'spotify:artist:4A0TivfinfALCAMJqqjZIk'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 223413,
#      'explicit': True,
#      'external_ids': {'isrc': 'GBARL1700772'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5bcTCxgc7xVfSaMV3RuVke'},
#      'href': 'https://api.spotify.com/v1/tracks/5bcTCxgc7xVfSaMV3RuVke',
#      'id': '5bcTCxgc7xVfSaMV3RuVke',
#      'is_local': False,
#      'name': 'Feels (feat. Pharrell Williams, Katy Perry & Big Sean)',
#      'popularity': 74,
#      'preview_url': 'https://p.scdn.co/mp3-preview/0c58b32cdd0231ce4dc3cc2fe63a71046fd9f586?cid=c39fbc66489441ce809290f1c586c0db',
#      'track_number': 8,
#      'type': 'track',
#      'uri': 'spotify:track:5bcTCxgc7xVfSaMV3RuVke'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0FWzNDaEu9jdgcYTbcOa4F'},
#         'href': 'https://api.spotify.com/v1/artists/0FWzNDaEu9jdgcYTbcOa4F',
#         'id': '0FWzNDaEu9jdgcYTbcOa4F',
#         'name': '3OH!3',
#         'type': 'artist',
#         'uri': 'spotify:artist:0FWzNDaEu9jdgcYTbcOa4F'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'GB',
#        'GR',
#        'GT',
#        'HN',
#        'HR',
#        'HU',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SI',
#        'SK',
#        'SV',
#        'TN',
#        'TR',
#        'UA',
#        'US',
#        'UY',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/10xgy5KkSpP3prnygQmFoN'},
#       'href': 'https://api.spotify.com/v1/albums/10xgy5KkSpP3prnygQmFoN',
#       'id': '10xgy5KkSpP3prnygQmFoN',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273bc12db3758aeb3b198fb362d',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02bc12db3758aeb3b198fb362d',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851bc12db3758aeb3b198fb362d',
#         'width': 64}],
#       'name': 'WANT (Deluxe)',
#       'release_date': '2009-01-16',
#       'release_date_precision': 'day',
#       'total_tracks': 15,
#       'type': 'album',
#       'uri': 'spotify:album:10xgy5KkSpP3prnygQmFoN'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0FWzNDaEu9jdgcYTbcOa4F'},
#        'href': 'https://api.spotify.com/v1/artists/0FWzNDaEu9jdgcYTbcOa4F',
#        'id': '0FWzNDaEu9jdgcYTbcOa4F',
#        'name': '3OH!3',
#        'type': 'artist',
#        'uri': 'spotify:artist:0FWzNDaEu9jdgcYTbcOa4F'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Pk9L2rUT7wj7queJvrlp5'},
#        'href': 'https://api.spotify.com/v1/artists/3Pk9L2rUT7wj7queJvrlp5',
#        'id': '3Pk9L2rUT7wj7queJvrlp5',
#        'name': 'Matt Squire',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Pk9L2rUT7wj7queJvrlp5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'GB',
#       'GR',
#       'GT',
#       'HN',
#       'HR',
#       'HU',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SI',
#       'SK',
#       'SV',
#       'TN',
#       'TR',
#       'UA',
#       'US',
#       'UY',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 202666,
#      'explicit': True,
#      'external_ids': {'isrc': 'USAT20902549'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1hBM2D1ULT3aeKuddSwPsK'},
#      'href': 'https://api.spotify.com/v1/tracks/1hBM2D1ULT3aeKuddSwPsK',
#      'id': '1hBM2D1ULT3aeKuddSwPsK',
#      'is_local': False,
#      'name': 'STARSTRUKK (feat. Katy Perry)',
#      'popularity': 62,
#      'preview_url': 'https://p.scdn.co/mp3-preview/d8d23619f598e56354bba6db9081605ecb019b99?cid=c39fbc66489441ce809290f1c586c0db',
#      'track_number': 13,
#      'type': 'track',
#      'uri': 'spotify:track:1hBM2D1ULT3aeKuddSwPsK'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hEurMDQu99nJRq8pTxO14'},
#         'href': 'https://api.spotify.com/v1/artists/0hEurMDQu99nJRq8pTxO14',
#         'id': '0hEurMDQu99nJRq8pTxO14',
#         'name': 'John Mayer',
#         'type': 'artist',
#         'uri': 'spotify:artist:0hEurMDQu99nJRq8pTxO14'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/712VoD72K500yLhhgqCyVe'},
#       'href': 'https://api.spotify.com/v1/albums/712VoD72K500yLhhgqCyVe',
#       'id': '712VoD72K500yLhhgqCyVe',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2738e3ab1cbd76d15dc64450a13',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e028e3ab1cbd76d15dc64450a13',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048518e3ab1cbd76d15dc64450a13',
#         'width': 64}],
#       'name': 'Paradise Valley',
#       'release_date': '2013-08-20',
#       'release_date_precision': 'day',
#       'total_tracks': 11,
#       'type': 'album',
#       'uri': 'spotify:album:712VoD72K500yLhhgqCyVe'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hEurMDQu99nJRq8pTxO14'},
#        'href': 'https://api.spotify.com/v1/artists/0hEurMDQu99nJRq8pTxO14',
#        'id': '0hEurMDQu99nJRq8pTxO14',
#        'name': 'John Mayer',
#        'type': 'artist',
#        'uri': 'spotify:artist:0hEurMDQu99nJRq8pTxO14'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#        'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#        'id': '6jJ0s89eD6GaHleKKya26X',
#        'name': 'Katy Perry',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 249933,
#      'explicit': False,
#      'external_ids': {'isrc': 'USSM11303945'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/7IByJvSqRFltGyiiIiL4wn'},
#      'href': 'https://api.spotify.com/v1/tracks/7IByJvSqRFltGyiiIiL4wn',
#      'id': '7IByJvSqRFltGyiiIiL4wn',
#      'is_local': False,
#      'name': 'Who You Love (feat. Katy Perry)',
#      'popularity': 64,
#      'preview_url': 'https://p.scdn.co/mp3-preview/189ff69a7243412de5d003bc52ffcbbc9496f238?cid=c39fbc66489441ce809290f1c586c0db',
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:7IByJvSqRFltGyiiIiL4wn'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Y5TRrQiqgUO4S36tzjIRZ'},
#         'href': 'https://api.spotify.com/v1/artists/5Y5TRrQiqgUO4S36tzjIRZ',
#         'id': '5Y5TRrQiqgUO4S36tzjIRZ',
#         'name': 'Timbaland',
#         'type': 'artist',
#         'uri': 'spotify:artist:5Y5TRrQiqgUO4S36tzjIRZ'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
# ...
#       'release_date': '2016-04-29',
#       'release_date_precision': 'day',
#       'total_tracks': 12,
#       'type': 'album',
#       'uri': 'spotify:album:1QKRhduQ3uuv5sXxcQ0j0K'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bHjVR4F2Tfq4Ha6x7K6wU'},
#        'href': 'https://api.spotify.com/v1/artists/5bHjVR4F2Tfq4Ha6x7K6wU',
#        'id': '5bHjVR4F2Tfq4Ha6x7K6wU',
#        'name': 'Rockabye Baby!',
#        'type': 'artist',
#        'uri': 'spotify:artist:5bHjVR4F2Tfq4Ha6x7K6wU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 223199,
#      'explicit': False,
#      'external_ids': {'isrc': 'USEWC1689978'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/7ogPk9PSUggLEcqe87gcwa'},
#      'href': 'https://api.spotify.com/v1/tracks/7ogPk9PSUggLEcqe87gcwa',
#      'id': '7ogPk9PSUggLEcqe87gcwa',
#      'is_local': False,
#      'name': 'Hello',
#      'popularity': 45,
#      'preview_url': 'https://p.scdn.co/mp3-preview/82a36b20683d4eda7409cfaffdf364a86b3ea423?cid=c39fbc66489441ce809290f1c586c0db',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:7ogPk9PSUggLEcqe87gcwa'},
#     {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64OP4jWm7ll75mxC1xIvT7'},
#         'href': 'https://api.spotify.com/v1/artists/64OP4jWm7ll75mxC1xIvT7',
#         'id': '64OP4jWm7ll75mxC1xIvT7',
#         'name': 'Branson Mohr Shayl',
#         'type': 'artist',
#         'uri': 'spotify:artist:64OP4jWm7ll75mxC1xIvT7'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0mjqi9Ta3J7yaPe7HHcZOu'},
#       'href': 'https://api.spotify.com/v1/albums/0mjqi9Ta3J7yaPe7HHcZOu',
#       'id': '0mjqi9Ta3J7yaPe7HHcZOu',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273fb5c1252864cb860f8da5853',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02fb5c1252864cb860f8da5853',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851fb5c1252864cb860f8da5853',
#         'width': 64}],
#       'name': 'Adele Port Ieva',
#       'release_date': '2020-09-30',
#       'release_date_precision': 'day',
#       'total_tracks': 5,
#       'type': 'album',
#       'uri': 'spotify:album:0mjqi9Ta3J7yaPe7HHcZOu'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64OP4jWm7ll75mxC1xIvT7'},
#        'href': 'https://api.spotify.com/v1/artists/64OP4jWm7ll75mxC1xIvT7',
#        'id': '64OP4jWm7ll75mxC1xIvT7',
#        'name': 'Branson Mohr Shayl',
#        'type': 'artist',
#        'uri': 'spotify:artist:64OP4jWm7ll75mxC1xIvT7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 138411,
#      'explicit': False,
#      'external_ids': {'isrc': 'QZNMT2020210'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6izVr81eVBI9f6TDC7llwc'},
#      'href': 'https://api.spotify.com/v1/tracks/6izVr81eVBI9f6TDC7llwc',
#      'id': '6izVr81eVBI9f6TDC7llwc',
#      'is_local': False,
#      'name': 'Buckridge Meadow Weiss',
#      'popularity': 42,
#      'preview_url': 'https://p.scdn.co/mp3-preview/3ec576b6ae79275e2f9cd410b77f6b0bd273c5ff?cid=c39fbc66489441ce809290f1c586c0db',
#      'track_number': 5,
#      'type': 'track',
#      'uri': 'spotify:track:6izVr81eVBI9f6TDC7llwc'},
#     {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64OP4jWm7ll75mxC1xIvT7'},
#         'href': 'https://api.spotify.com/v1/artists/64OP4jWm7ll75mxC1xIvT7',
#         'id': '64OP4jWm7ll75mxC1xIvT7',
#         'name': 'Branson Mohr Shayl',
#         'type': 'artist',
#         'uri': 'spotify:artist:64OP4jWm7ll75mxC1xIvT7'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0mjqi9Ta3J7yaPe7HHcZOu'},
#       'href': 'https://api.spotify.com/v1/albums/0mjqi9Ta3J7yaPe7HHcZOu',
#       'id': '0mjqi9Ta3J7yaPe7HHcZOu',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273fb5c1252864cb860f8da5853',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02fb5c1252864cb860f8da5853',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851fb5c1252864cb860f8da5853',
#         'width': 64}],
#       'name': 'Adele Port Ieva',
#       'release_date': '2020-09-30',
#       'release_date_precision': 'day',
#       'total_tracks': 5,
#       'type': 'album',
#       'uri': 'spotify:album:0mjqi9Ta3J7yaPe7HHcZOu'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64OP4jWm7ll75mxC1xIvT7'},
#        'href': 'https://api.spotify.com/v1/artists/64OP4jWm7ll75mxC1xIvT7',
#        'id': '64OP4jWm7ll75mxC1xIvT7',
#        'name': 'Branson Mohr Shayl',
#        'type': 'artist',
#        'uri': 'spotify:artist:64OP4jWm7ll75mxC1xIvT7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 144439,
#      'explicit': False,
#      'external_ids': {'isrc': 'QZNMT2020208'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/41xQ8Oli5b50X1AmJz6hYM'},
#      'href': 'https://api.spotify.com/v1/tracks/41xQ8Oli5b50X1AmJz6hYM',
#      'id': '41xQ8Oli5b50X1AmJz6hYM',
#      'is_local': False,
#      'name': 'Kiehn Corners Ola',
#      'popularity': 41,
#      'preview_url': 'https://p.scdn.co/mp3-preview/9461c4a1f16db28cc6e46b2e75cd0c3e8fc2e583?cid=c39fbc66489441ce809290f1c586c0db',
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:41xQ8Oli5b50X1AmJz6hYM'},
#     {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64OP4jWm7ll75mxC1xIvT7'},
#         'href': 'https://api.spotify.com/v1/artists/64OP4jWm7ll75mxC1xIvT7',
#         'id': '64OP4jWm7ll75mxC1xIvT7',
#         'name': 'Branson Mohr Shayl',
#         'type': 'artist',
#         'uri': 'spotify:artist:64OP4jWm7ll75mxC1xIvT7'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0mjqi9Ta3J7yaPe7HHcZOu'},
#       'href': 'https://api.spotify.com/v1/albums/0mjqi9Ta3J7yaPe7HHcZOu',
#       'id': '0mjqi9Ta3J7yaPe7HHcZOu',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273fb5c1252864cb860f8da5853',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02fb5c1252864cb860f8da5853',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851fb5c1252864cb860f8da5853',
#         'width': 64}],
#       'name': 'Adele Port Ieva',
#       'release_date': '2020-09-30',
#       'release_date_precision': 'day',
#       'total_tracks': 5,
#       'type': 'album',
#       'uri': 'spotify:album:0mjqi9Ta3J7yaPe7HHcZOu'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64OP4jWm7ll75mxC1xIvT7'},
#        'href': 'https://api.spotify.com/v1/artists/64OP4jWm7ll75mxC1xIvT7',
#        'id': '64OP4jWm7ll75mxC1xIvT7',
#        'name': 'Branson Mohr Shayl',
#        'type': 'artist',
#        'uri': 'spotify:artist:64OP4jWm7ll75mxC1xIvT7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 129500,
#      'explicit': False,
#      'external_ids': {'isrc': 'QZNMT2020209'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0lGeQAxXlG2z9JczHazhgb'},
#      'href': 'https://api.spotify.com/v1/tracks/0lGeQAxXlG2z9JczHazhgb',
#      'id': '0lGeQAxXlG2z9JczHazhgb',
#      'is_local': False,
#      'name': 'Dietrich Parkway Scor',
#      'popularity': 40,
#      'preview_url': 'https://p.scdn.co/mp3-preview/048847a02d7ff183d7ee7b5b0822990fee85188b?cid=c39fbc66489441ce809290f1c586c0db',
#      'track_number': 4,
#      'type': 'track',
#      'uri': 'spotify:track:0lGeQAxXlG2z9JczHazhgb'}],
#    'limit': 50,
#    'next': 'https://api.spotify.com/v1/search?query=Adele&type=track&offset=50&limit=50',
#    'offset': 0,
#    'previous': None,
#    'total': 9454}}]

# %%
my_3_artists[0]["tracks"]["total"]+my_3_artists[1]["tracks"]["total"]+my_3_artists[2]["tracks"]["total"]
# Out:
# 19322

# %%
my_3_artists[0]["tracks"]["items"][7]["uri"]
# Out:
# 'spotify:track:5bcTCxgc7xVfSaMV3RuVke'

# %%
#Function to get the artists involved in a song:

def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
#here we are returning to using the results set from our earlier query 
#but you could also build upon any other results from the API
#go back and rerun results query
my_track = results["tracks"]["items"][5]

# %%
get_artists_from_track(my_track)
# Out:
# ['The Weeknd', 'Daft Punk']

# %%
#Function to get the "id's" of the artists from a track:

def get_artists_ids_from_track(track):
    return[artist["id"] for artist in track["artists"]]

# %%
#part 2 of this function 

get_artists_ids_from_track(my_track)
# Out:
# ['1Xyo4u8uXC1ZmMpatF05PJ', '4tZwfgrHOc3mvqYlEYSvVi']

# %% [markdown]
# ### Playlists
#
# We will need to collect a "database" of songs. Playlists are a good way to access relatively large amounts of songs.
#
# do you already have a playlist of your own you can use ?
#
# do one of your classmates have a great playlist for this?
#
# or can you find a playlist on spotify which suits your needs ?
#
# hint: this is a shortcut to doing this part of your MVP

# %%
#I am using an example playlist from spotify - 2020 hits&best music

#read a playlist 

playlist_id = 'spotify:user:spotifycharts:playlist:6FKDzNYZ8IW1pvYVF4zUN2'
results = sp.playlist(playlist_id)
print(json.dumps(results, indent=4))
# Out:
# {
#     "collaborative": false,
#     "description": "updated with new songs randomly *** insta @alexmarty.00 *** dm to request songs&#x2F;remove songs",
#     "external_urls": {
#         "spotify": "https://open.spotify.com/playlist/6FKDzNYZ8IW1pvYVF4zUN2"
#     },
#     "followers": {
#         "href": null,
#         "total": 2860
#     },
#     "href": "https://api.spotify.com/v1/playlists/6FKDzNYZ8IW1pvYVF4zUN2?additional_types=track",
#     "id": "6FKDzNYZ8IW1pvYVF4zUN2",
#     "images": [
#         {
#             "height": null,
#             "url": "https://i.scdn.co/image/ab67706c0000bebb87aeae5e0d895b0f0164e69e",
#             "width": null
#         }
#     ],
#     "name": "Longest Playlist on Spotify",
#     "owner": {
#         "display_name": "Alex Marty",
#         "external_urls": {
#             "spotify": "https://open.spotify.com/user/exiedous"
#         },
#         "href": "https://api.spotify.com/v1/users/exiedous",
#         "id": "exiedous",
#         "type": "user",
#         "uri": "spotify:user:exiedous"
#     },
#     "primary_color": null,
#     "public": true,
#     "snapshot_id": "MTUyNCxhYmMwZWZhZDZkMmQ4NTE0YzVjOTMwNTZiOGE0YTE5NmM4YTEzN2Jm",
#     "tracks": {
#         "href": "https://api.spotify.com/v1/playlists/6FKDzNYZ8IW1pvYVF4zUN2/tracks?offset=0&limit=100&additional_types=track",
#         "items": [
#             {
#                 "added_at": "2017-08-03T23:43:14Z",
#                 "added_by": {
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/user/exiedous"
#                     },
#                     "href": "https://api.spotify.com/v1/users/exiedous",
#                     "id": "exiedous",
#                     "type": "user",
#                     "uri": "spotify:user:exiedous"
#                 },
#                 "is_local": false,
#                 "primary_color": null,
#                 "track": {
#                     "album": {
#                         "album_type": "album",
#                         "artists": [
#                             {
#                                 "external_urls": {
#                                     "spotify": "https://open.spotify.com/artist/6n28c9qs9hNGriNa72b26u"
#                                 },
#                                 "href": "https://api.spotify.com/v1/artists/6n28c9qs9hNGriNa72b26u",
#                                 "id": "6n28c9qs9hNGriNa72b26u",
#                                 "name": "PNAU",
#                                 "type": "artist",
#                                 "uri": "spotify:artist:6n28c9qs9hNGriNa72b26u"
#                             }
#                         ],
#                         "available_markets": [],
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/album/4r6fRqJ6wWnlci4hRabi08"
#                         },
#                         "href": "https://api.spotify.com/v1/albums/4r6fRqJ6wWnlci4hRabi08",
#                         "id": "4r6fRqJ6wWnlci4hRabi08",
#                         "images": [
#                             {
#                                 "height": 640,
#                                 "url": "https://i.scdn.co/image/ab67616d0000b27373b70fa58651c155ec3fff3a",
#                                 "width": 640
#                             },
#                             {
#                                 "height": 300,
#                                 "url": "https://i.scdn.co/image/ab67616d00001e0273b70fa58651c155ec3fff3a",
#                                 "width": 300
#                             },
#                             {
#                                 "height": 64,
#                                 "url": "https://i.scdn.co/image/ab67616d0000485173b70fa58651c155ec3fff3a",
#                                 "width": 64
#                             }
#                         ],
#                         "name": "PNAU (Tour Edition)",
#                         "release_date": "2009-01-01",
#                         "release_date_precision": "day",
#                         "total_tracks": 18,
#                         "type": "album",
#                         "uri": "spotify:album:4r6fRqJ6wWnlci4hRabi08"
#                     },
#                     "artists": [
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/6n28c9qs9hNGriNa72b26u"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/6n28c9qs9hNGriNa72b26u",
#                             "id": "6n28c9qs9hNGriNa72b26u",
#                             "name": "PNAU",
#                             "type": "artist",
#                             "uri": "spotify:artist:6n28c9qs9hNGriNa72b26u"
#                         }
#                     ],
#                     "available_markets": [],
#                     "disc_number": 1,
#                     "duration_ms": 235106,
#                     "episode": false,
#                     "explicit": false,
#                     "external_ids": {
#                         "isrc": "AUNV00700748"
#                     },
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/track/6pGUGTIaZ1H4jKHIL4Fged"
#                     },
#                     "href": "https://api.spotify.com/v1/tracks/6pGUGTIaZ1H4jKHIL4Fged",
#                     "id": "6pGUGTIaZ1H4jKHIL4Fged",
#                     "is_local": false,
#                     "name": "Wild Strawberries",
#                     "popularity": 0,
#                     "preview_url": null,
#                     "track": true,
#                     "track_number": 2,
#                     "type": "track",
#                     "uri": "spotify:track:6pGUGTIaZ1H4jKHIL4Fged"
#                 },
#                 "video_thumbnail": {
#                     "url": null
#                 }
#             },
#             {
#                 "added_at": "2017-08-03T23:40:58Z",
#                 "added_by": {
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/user/exiedous"
#                     },
#                     "href": "https://api.spotify.com/v1/users/exiedous",
#                     "id": "exiedous",
#                     "type": "user",
#                     "uri": "spotify:user:exiedous"
#                 },
#                 "is_local": false,
#                 "primary_color": null,
#                 "track": {
#                     "album": {
#                         "album_type": "album",
#                         "artists": [
#                             {
#                                 "external_urls": {
#                                     "spotify": "https://open.spotify.com/artist/5j4HeCoUlzhfWtjAfM1acR"
#                                 },
#                                 "href": "https://api.spotify.com/v1/artists/5j4HeCoUlzhfWtjAfM1acR",
#                                 "id": "5j4HeCoUlzhfWtjAfM1acR",
#                                 "name": "Stromae",
#                                 "type": "artist",
#                                 "uri": "spotify:artist:5j4HeCoUlzhfWtjAfM1acR"
#                             }
#                         ],
#                         "available_markets": [],
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/album/4WW3ME0M2dUoAK5hmbXsN7"
#                         },
#                         "href": "https://api.spotify.com/v1/albums/4WW3ME0M2dUoAK5hmbXsN7",
#                         "id": "4WW3ME0M2dUoAK5hmbXsN7",
#                         "images": [
#                             {
#                                 "height": 640,
#                                 "url": "https://i.scdn.co/image/ab67616d0000b2738a6bb98baff4c9b15f9972fc",
#                                 "width": 640
#                             },
#                             {
#                                 "height": 300,
#                                 "url": "https://i.scdn.co/image/ab67616d00001e028a6bb98baff4c9b15f9972fc",
#                                 "width": 300
#                             },
#                             {
#                                 "height": 64,
#                                 "url": "https://i.scdn.co/image/ab67616d000048518a6bb98baff4c9b15f9972fc",
#                                 "width": 64
#                             }
#                         ],
#                         "name": "racine carr\u00e9e",
#                         "release_date": "2013-01-01",
#                         "release_date_precision": "day",
#                         "total_tracks": 13,
#                         "type": "album",
#                         "uri": "spotify:album:4WW3ME0M2dUoAK5hmbXsN7"
#                     },
#                     "artists": [
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/5j4HeCoUlzhfWtjAfM1acR"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/5j4HeCoUlzhfWtjAfM1acR",
#                             "id": "5j4HeCoUlzhfWtjAfM1acR",
#                             "name": "Stromae",
#                             "type": "artist",
#                             "uri": "spotify:artist:5j4HeCoUlzhfWtjAfM1acR"
#                         }
#                     ],
#                     "available_markets": [],
#                     "disc_number": 1,
#                     "duration_ms": 232146,
#                     "episode": false,
#                     "explicit": false,
#                     "external_ids": {
#                         "isrc": "BET671300160"
#                     },
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/track/09TcIuH1ZO7i4vicWKoaN2"
#                     },
#                     "href": "https://api.spotify.com/v1/tracks/09TcIuH1ZO7i4vicWKoaN2",
#                     "id": "09TcIuH1ZO7i4vicWKoaN2",
#                     "is_local": false,
#                     "name": "Papaoutai",
#                     "popularity": 0,
#                     "preview_url": null,
#                     "track": true,
#                     "track_number": 2,
#                     "type": "track",
#                     "uri": "spotify:track:09TcIuH1ZO7i4vicWKoaN2"
#                 },
#                 "video_thumbnail": {
#                     "url": null
#                 }
#             },
#             {
#                 "added_at": "2017-08-03T23:43:10Z",
#                 "added_by": {
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/user/exiedous"
#                     },
#                     "href": "https://api.spotify.com/v1/users/exiedous",
#                     "id": "exiedous",
#                     "type": "user",
#                     "uri": "spotify:user:exiedous"
#                 },
#                 "is_local": false,
#                 "primary_color": null,
#                 "track": {
#                     "album": {
#                         "album_type": "album",
#                         "artists": [
#                             {
#                                 "external_urls": {
#                                     "spotify": "https://open.spotify.com/artist/0NKDgy9j66h3DLnN8qu1bB"
#                                 },
#                                 "href": "https://api.spotify.com/v1/artists/0NKDgy9j66h3DLnN8qu1bB",
#                                 "id": "0NKDgy9j66h3DLnN8qu1bB",
#                                 "name": "Eurythmics",
#                                 "type": "artist",
#                                 "uri": "spotify:artist:0NKDgy9j66h3DLnN8qu1bB"
#                             },
#                             {
#                                 "external_urls": {
#                                     "spotify": "https://open.spotify.com/artist/5MspMQqdVbdwP6ax3GXqum"
#                                 },
#                                 "href": "https://api.spotify.com/v1/artists/5MspMQqdVbdwP6ax3GXqum",
#                                 "id": "5MspMQqdVbdwP6ax3GXqum",
#                                 "name": "Annie Lennox",
#                                 "type": "artist",
#                                 "uri": "spotify:artist:5MspMQqdVbdwP6ax3GXqum"
#                             },
#                             {
#                                 "external_urls": {
#                                     "spotify": "https://open.spotify.com/artist/7gcCQIlkkfbul5Mt0jBQkg"
#                                 },
#                                 "href": "https://api.spotify.com/v1/artists/7gcCQIlkkfbul5Mt0jBQkg",
#                                 "id": "7gcCQIlkkfbul5Mt0jBQkg",
#                                 "name": "Dave Stewart",
#                                 "type": "artist",
#                                 "uri": "spotify:artist:7gcCQIlkkfbul5Mt0jBQkg"
#                             }
#                         ],
#                         "available_markets": [
#                             "AD",
#                             "AE",
#                             "AL",
#                             "AR",
#                             "AT",
#                             "AU",
#                             "BA",
#                             "BE",
#                             "BG",
#                             "BH",
#                             "BO",
#                             "BR",
#                             "BY",
#                             "CA",
#                             "CH",
#                             "CL",
#                             "CO",
#                             "CR",
#                             "CY",
#                             "CZ",
#                             "DE",
#                             "DK",
#                             "DO",
#                             "DZ",
#                             "EC",
#                             "EE",
#                             "EG",
#                             "ES",
#                             "FI",
#                             "FR",
#                             "GB",
#                             "GR",
#                             "GT",
#                             "HK",
#                             "HN",
#                             "HR",
#                             "HU",
#                             "ID",
#                             "IE",
#                             "IL",
#                             "IN",
#                             "IS",
#                             "IT",
#                             "JO",
#                             "JP",
#                             "KW",
#                             "KZ",
#                             "LB",
#                             "LI",
#                             "LT",
#                             "LU",
#                             "LV",
#                             "MA",
#                             "MC",
#                             "MD",
#                             "ME",
#                             "MK",
#                             "MT",
#                             "MX",
#                             "MY",
#                             "NI",
#                             "NL",
#                             "NO",
#                             "NZ",
#                             "OM",
#                             "PA",
#                             "PE",
#                             "PH",
#                             "PL",
#                             "PS",
#                             "PT",
#                             "PY",
#                             "QA",
#                             "RO",
#                             "RS",
#                             "RU",
#                             "SA",
#                             "SE",
#                             "SG",
#                             "SI",
#                             "SK",
#                             "SV",
#                             "TH",
#                             "TN",
#                             "TR",
#                             "TW",
#                             "UA",
#                             "US",
#                             "UY",
#                             "VN",
#                             "XK",
#                             "ZA"
#                         ],
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/album/5jNDWA19BJbE24x1UUJGRY"
#                         },
#                         "href": "https://api.spotify.com/v1/albums/5jNDWA19BJbE24x1UUJGRY",
#                         "id": "5jNDWA19BJbE24x1UUJGRY",
#                         "images": [
#                             {
#                                 "height": 640,
#                                 "url": "https://i.scdn.co/image/ab67616d0000b273b3994c94dfb241923664bb4d",
#                                 "width": 640
#                             },
#                             {
#                                 "height": 300,
#                                 "url": "https://i.scdn.co/image/ab67616d00001e02b3994c94dfb241923664bb4d",
#                                 "width": 300
#                             },
#                             {
#                                 "height": 64,
#                                 "url": "https://i.scdn.co/image/ab67616d00004851b3994c94dfb241923664bb4d",
#                                 "width": 64
#                             }
#                         ],
#                         "name": "Sweet Dreams (Are Made Of This)",
#                         "release_date": "1983-01-04",
#                         "release_date_precision": "day",
#                         "total_tracks": 16,
#                         "type": "album",
#                         "uri": "spotify:album:5jNDWA19BJbE24x1UUJGRY"
#                     },
#                     "artists": [
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/0NKDgy9j66h3DLnN8qu1bB"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/0NKDgy9j66h3DLnN8qu1bB",
#                             "id": "0NKDgy9j66h3DLnN8qu1bB",
#                             "name": "Eurythmics",
#                             "type": "artist",
#                             "uri": "spotify:artist:0NKDgy9j66h3DLnN8qu1bB"
#                         },
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/5MspMQqdVbdwP6ax3GXqum"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/5MspMQqdVbdwP6ax3GXqum",
#                             "id": "5MspMQqdVbdwP6ax3GXqum",
#                             "name": "Annie Lennox",
#                             "type": "artist",
#                             "uri": "spotify:artist:5MspMQqdVbdwP6ax3GXqum"
#                         },
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/7gcCQIlkkfbul5Mt0jBQkg"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/7gcCQIlkkfbul5Mt0jBQkg",
#                             "id": "7gcCQIlkkfbul5Mt0jBQkg",
#                             "name": "Dave Stewart",
#                             "type": "artist",
#                             "uri": "spotify:artist:7gcCQIlkkfbul5Mt0jBQkg"
#                         }
#                     ],
#                     "available_markets": [
#                         "AD",
#                         "AE",
#                         "AL",
#                         "AR",
#                         "AT",
#                         "AU",
#                         "BA",
#                         "BE",
#                         "BG",
#                         "BH",
#                         "BO",
#                         "BR",
#                         "BY",
#                         "CA",
#                         "CH",
#                         "CL",
#                         "CO",
#                         "CR",
#                         "CY",
#                         "CZ",
#                         "DE",
#                         "DK",
#                         "DO",
#                         "DZ",
#                         "EC",
#                         "EE",
#                         "EG",
#                         "ES",
#                         "FI",
#                         "FR",
#                         "GB",
#                         "GR",
#                         "GT",
#                         "HK",
#                         "HN",
#                         "HR",
#                         "HU",
#                         "ID",
#                         "IE",
#                         "IL",
#                         "IN",
#                         "IS",
#                         "IT",
#                         "JO",
#                         "JP",
#                         "KW",
#                         "KZ",
#                         "LB",
#                         "LI",
#                         "LT",
#                         "LU",
#                         "LV",
#                         "MA",
#                         "MC",
#                         "MD",
#                         "ME",
#                         "MK",
#                         "MT",
#                         "MX",
#                         "MY",
#                         "NI",
#                         "NL",
#                         "NO",
#                         "NZ",
#                         "OM",
#                         "PA",
#                         "PE",
#                         "PH",
#                         "PL",
#                         "PS",
#                         "PT",
#                         "PY",
#                         "QA",
#                         "RO",
#                         "RS",
#                         "RU",
#                         "SA",
#                         "SE",
#                         "SG",
#                         "SI",
#                         "SK",
#                         "SV",
#                         "TH",
#                         "TN",
#                         "TR",
#                         "TW",
#                         "UA",
#                         "US",
#                         "UY",
#                         "VN",
#                         "XK",
#                         "ZA"
#                     ],
#                     "disc_number": 1,
#                     "duration_ms": 216933,
#                     "episode": false,
#                     "explicit": false,
#                     "external_ids": {
#                         "isrc": "GBARL0300589"
#                     },
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/track/1TfqLAPs4K3s2rJMoCokcS"
#                     },
#                     "href": "https://api.spotify.com/v1/tracks/1TfqLAPs4K3s2rJMoCokcS",
#                     "id": "1TfqLAPs4K3s2rJMoCokcS",
#                     "is_local": false,
#                     "name": "Sweet Dreams (Are Made of This) - Remastered",
#                     "popularity": 80,
#                     "preview_url": "https://p.scdn.co/mp3-preview/47477574da2591c98c035543bfb2ec4ee82458fd?cid=c39fbc66489441ce809290f1c586c0db",
#                     "track": true,
#                     "track_number": 6,
#                     "type": "track",
#                     "uri": "spotify:track:1TfqLAPs4K3s2rJMoCokcS"
#                 },
#                 "video_thumbnail": {
#                     "url": null
#                 }
#             },
#             {
#                 "added_at": "2017-08-03T23:45:06Z",
#                 "added_by": {
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/user/exiedous"
#                     },
#                     "href": "https://api.spotify.com/v1/users/exiedous",
#                     "id": "exiedous",
#                     "type": "user",
#                     "uri": "spotify:user:exiedous"
#                 },
#                 "is_local": false,
#                 "primary_color": null,
#                 "track": {
#                     "album": {
#                         "album_type": "album",
#                         "artists": [
#                             {
#                                 "external_urls": {
#                                     "spotify": "https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp"
#                                 },
#                                 "href": "https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp",
#                                 "id": "36QJpDe2go2KgaRleHCDTp",
#                                 "name": "Led Zeppelin",
#                                 "type": "artist",
#                                 "uri": "spotify:artist:36QJpDe2go2KgaRleHCDTp"
#                             }
#                         ],
#                         "available_markets": [
#                             "AD",
#                             "AE",
#                             "AL",
#                             "AR",
#                             "AT",
#                             "AU",
#                             "BA",
#                             "BE",
#                             "BG",
#                             "BH",
#                             "BO",
#                             "BR",
#                             "BY",
#                             "CA",
#                             "CH",
#                             "CL",
#                             "CO",
#                             "CR",
#                             "CY",
#                             "CZ",
#                             "DE",
#                             "DK",
#                             "DO",
#                             "DZ",
#                             "EC",
#                             "EE",
#                             "EG",
#                             "ES",
#                             "FI",
#                             "FR",
#                             "GB",
#                             "GR",
#                             "GT",
#                             "HK",
#                             "HN",
#                             "HR",
#                             "HU",
#                             "ID",
#                             "IE",
#                             "IL",
#                             "IN",
#                             "IS",
#                             "IT",
#                             "JO",
#                             "KW",
#                             "KZ",
#                             "LB",
#                             "LT",
#                             "LU",
#                             "LV",
#                             "MA",
#                             "MC",
#                             "MD",
#                             "ME",
#                             "MK",
#                             "MT",
#                             "MX",
#                             "MY",
#                             "NI",
#                             "NL",
#                             "NO",
#                             "NZ",
#                             "OM",
#                             "PA",
#                             "PE",
#                             "PH",
#                             "PL",
#                             "PT",
#                             "PY",
#                             "QA",
#                             "RO",
#                             "RS",
#                             "RU",
#                             "SA",
#                             "SE",
#                             "SG",
#                             "SI",
#                             "SK",
#                             "SV",
#                             "TH",
#                             "TN",
#                             "TR",
#                             "TW",
#                             "UA",
#                             "US",
#                             "UY",
#                             "VN",
#                             "XK",
#                             "ZA"
#                         ],
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/album/1Ugdi2OTxKopVVqsprp5pb"
#                         },
#                         "href": "https://api.spotify.com/v1/albums/1Ugdi2OTxKopVVqsprp5pb",
#                         "id": "1Ugdi2OTxKopVVqsprp5pb",
#                         "images": [
#                             {
#                                 "height": 640,
#                                 "url": "https://i.scdn.co/image/ab67616d0000b273cd25ce73e3eddeedb995fcee",
#                                 "width": 640
#                             },
#                             {
#                                 "height": 300,
#                                 "url": "https://i.scdn.co/image/ab67616d00001e02cd25ce73e3eddeedb995fcee",
#                                 "width": 300
#                             },
#                             {
#                                 "height": 64,
#                                 "url": "https://i.scdn.co/image/ab67616d00004851cd25ce73e3eddeedb995fcee",
#                                 "width": 64
#                             }
#                         ],
#                         "name": "Led Zeppelin IV",
#                         "release_date": "1971-11-08",
#                         "release_date_precision": "day",
#                         "total_tracks": 8,
#                         "type": "album",
#                         "uri": "spotify:album:1Ugdi2OTxKopVVqsprp5pb"
#                     },
#                     "artists": [
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp",
#                             "id": "36QJpDe2go2KgaRleHCDTp",
#                             "name": "Led Zeppelin",
#                             "type": "artist",
#                             "uri": "spotify:artist:36QJpDe2go2KgaRleHCDTp"
#                         }
#                     ],
#                     "available_markets": [
#                         "AD",
#                         "AE",
#                         "AL",
#                         "AR",
#                         "AT",
#                         "AU",
#                         "BA",
#                         "BE",
#                         "BG",
#                         "BH",
#                         "BO",
#                         "BR",
#                         "BY",
#                         "CA",
#                         "CH",
#                         "CL",
#                         "CO",
#                         "CR",
#                         "CY",
#                         "CZ",
#                         "DE",
#                         "DK",
#                         "DO",
#                         "DZ",
#                         "EC",
#                         "EE",
#                         "EG",
#                         "ES",
#                         "FI",
#                         "FR",
#                         "GB",
#                         "GR",
#                         "GT",
#                         "HK",
#                         "HN",
#                         "HR",
#                         "HU",
#                         "ID",
#                         "IE",
#                         "IL",
#                         "IN",
#                         "IS",
#                         "IT",
#                         "JO",
#                         "KW",
#                         "KZ",
#                         "LB",
#                         "LT",
#                         "LU",
#                         "LV",
#                         "MA",
#                         "MC",
#                         "MD",
#                         "ME",
#                         "MK",
#                         "MT",
#                         "MX",
#                         "MY",
#                         "NI",
#                         "NL",
#                         "NO",
#                         "NZ",
#                         "OM",
#                         "PA",
#                         "PE",
#                         "PH",
#                         "PL",
#                         "PT",
#                         "PY",
#                         "QA",
#                         "RO",
#                         "RS",
#                         "RU",
#                         "SA",
#                         "SE",
#                         "SG",
#                         "SI",
#                         "SK",
#                         "SV",
#                         "TH",
#                         "TN",
#                         "TR",
#                         "TW",
#                         "UA",
#                         "US",
#                         "UY",
#                         "VN",
#                         "XK",
#                         "ZA"
#                     ],
#                     "disc_number": 1,
#                     "duration_ms": 219800,
#                     "episode": false,
#                     "explicit": false,
#                     "external_ids": {
#                         "isrc": "USAT29900619"
#                     },
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/track/3w2GGz0HjIu9OcWXINRFJR"
#                     },
#                     "href": "https://api.spotify.com/v1/tracks/3w2GGz0HjIu9OcWXINRFJR",
#                     "id": "3w2GGz0HjIu9OcWXINRFJR",
#                     "is_local": false,
#                     "name": "Rock and Roll - 1990 Remaster",
#                     "popularity": 58,
#                     "preview_url": "https://p.scdn.co/mp3-preview/35db3581cc5fde6b23c7904cefdaddc58b24ff75?cid=c39fbc66489441ce809290f1c586c0db",
#                     "track": true,
#                     "track_number": 2,
#                     "type": "track",
#                     "uri": "spotify:track:3w2GGz0HjIu9OcWXINRFJR"
#                 },
#                 "video_thumbnail": {
#                     "url": null
#                 }
#             },
#             {
#                 "added_at": "2017-08-03T23:41:13Z",
#                 "added_by": {
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/user/exiedous"
#                     },
#                     "href": "https://api.spotify.com/v1/users/exiedous",
#                     "id": "exiedous",
#                     "type": "user",
#                     "uri": "spotify:user:exiedous"
#                 },
#                 "is_local": false,
#                 "primary_color": null,
#                 "track": {
#                     "album": {
#                         "album_type": "album",
#                         "artists": [
#                             {
#                                 "external_urls": {
#                                     "spotify": "https://open.spotify.com/artist/07YZf4WDAMNwqr4jfgOZ8y"
#                                 },
#                                 "href": "https://api.spotify.com/v1/artists/07YZf4WDAMNwqr4jfgOZ8y",
#                                 "id": "07YZf4WDAMNwqr4jfgOZ8y",
#                                 "name": "Jason Derulo",
#                                 "type": "artist",
#                                 "uri": "spotify:artist:07YZf4WDAMNwqr4jfgOZ8y"
#                             }
#                         ],
#                         "available_markets": [
#                             "AU",
#                             "GB",
#                             "IE",
#                             "NZ"
#                         ],
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/album/45WiY2DUJyqbIKfHnQo4lN"
#                         },
#                         "href": "https://api.spotify.com/v1/albums/45WiY2DUJyqbIKfHnQo4lN",
#                         "id": "45WiY2DUJyqbIKfHnQo4lN",
#                         "images": [
#                             {
#                                 "height": 640,
#                                 "url": "https://i.scdn.co/image/ab67616d0000b273341bcc4171814393eb34a2bf",
#                                 "width": 640
#                             },
#                             {
#                                 "height": 300,
#                                 "url": "https://i.scdn.co/image/ab67616d00001e02341bcc4171814393eb34a2bf",
#                                 "width": 300
#                             },
#                             {
#                                 "height": 64,
#                                 "url": "https://i.scdn.co/image/ab67616d00004851341bcc4171814393eb34a2bf",
#                                 "width": 64
#                             }
#                         ],
#                         "name": "Tattoos (Special Edition)",
#                         "release_date": "2013-09-10",
#                         "release_date_precision": "day",
#                         "total_tracks": 18,
#                         "type": "album",
#                         "uri": "spotify:album:45WiY2DUJyqbIKfHnQo4lN"
#                     },
#                     "artists": [
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/07YZf4WDAMNwqr4jfgOZ8y"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/07YZf4WDAMNwqr4jfgOZ8y",
#                             "id": "07YZf4WDAMNwqr4jfgOZ8y",
#                             "name": "Jason Derulo",
#                             "type": "artist",
#                             "uri": "spotify:artist:07YZf4WDAMNwqr4jfgOZ8y"
#                         },
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/17lzZA2AlOHwCwFALHttmp"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/17lzZA2AlOHwCwFALHttmp",
#                             "id": "17lzZA2AlOHwCwFALHttmp",
#                             "name": "2 Chainz",
#                             "type": "artist",
#                             "uri": "spotify:artist:17lzZA2AlOHwCwFALHttmp"
#                         }
#                     ],
#                     "available_markets": [
#                         "AU",
#                         "GB",
#                         "IE",
#                         "NZ"
#                     ],
#                     "disc_number": 1,
#                     "duration_ms": 177685,
#                     "episode": false,
#                     "explicit": true,
#                     "external_ids": {
#                         "isrc": "USWB11302648"
#                     },
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/track/4X4tgBEUiT6WqB2oTJ5ynH"
#                     },
#                     "href": "https://api.spotify.com/v1/tracks/4X4tgBEUiT6WqB2oTJ5ynH",
#                     "id": "4X4tgBEUiT6WqB2oTJ5ynH",
#                     "is_local": false,
#                     "name": "Talk Dirty (feat. 2 Chainz)",
#                     "popularity": 55,
#                     "preview_url": "https://p.scdn.co/mp3-preview/222364acc54017734b3e55a124e41106849e76f8?cid=c39fbc66489441ce809290f1c586c0db",
#                     "track": true,
#                     "track_number": 2,
#                     "type": "track",
#                     "uri": "spotify:track:4X4tgBEUiT6WqB2oTJ5ynH"
#                 },
#                 "video_thumbnail": {
#                     "url": null
#                 }
#             },
#             {
#                 "added_at": "2017-08-03T23:41:14Z",
#                 "added_by": {
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/user/exiedous"
#                     },
#                     "href": "https://api.spotify.com/v1/users/exiedous",
#                     "id": "exiedous",
#                     "type": "user",
#                     "uri": "spotify:user:exiedous"
#                 },
#                 "is_local": false,
#                 "primary_color": null,
#                 "track": {
#                     "album": {
#                         "album_type": "album",
#                         "artists": [
#                             {
#                                 "external_urls": {
#                                     "spotify": "https://open.spotify.com/artist/1bT7m67vi78r2oqvxrP3X5"
#                                 },
#                                 "href": "https://api.spotify.com/v1/artists/1bT7m67vi78r2oqvxrP3X5",
#                                 "id": "1bT7m67vi78r2oqvxrP3X5",
#                                 "name": "Naughty Boy",
#                                 "type": "artist",
#                                 "uri": "spotify:artist:1bT7m67vi78r2oqvxrP3X5"
#                             }
#                         ],
#                         "available_markets": [
#                             "CA",
#                             "MX",
#                             "US"
#                         ],
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/album/2SVSPhDBqChBe10hJh5owv"
#                         },
#                         "href": "https://api.spotify.com/v1/albums/2SVSPhDBqChBe10hJh5owv",
#                         "id": "2SVSPhDBqChBe10hJh5owv",
#                         "images": [
#                             {
#                                 "height": 640,
#                                 "url": "https://i.scdn.co/image/ab67616d0000b27384c36b88540d1c658a02dfc9",
#                                 "width": 640
#                             },
#                             {
#                                 "height": 300,
#                                 "url": "https://i.scdn.co/image/ab67616d00001e0284c36b88540d1c658a02dfc9",
#                                 "width": 300
#                             },
#                             {
#                                 "height": 64,
#                                 "url": "https://i.scdn.co/image/ab67616d0000485184c36b88540d1c658a02dfc9",
#                                 "width": 64
#                             }
#                         ],
#                         "name": "Hotel Cabana (Deluxe Version)",
#                         "release_date": "2014-01-01",
#                         "release_date_precision": "day",
#                         "total_tracks": 21,
#                         "type": "album",
#                         "uri": "spotify:album:2SVSPhDBqChBe10hJh5owv"
#                     },
#                     "artists": [
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/1bT7m67vi78r2oqvxrP3X5"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/1bT7m67vi78r2oqvxrP3X5",
#                             "id": "1bT7m67vi78r2oqvxrP3X5",
#                             "name": "Naughty Boy",
#                             "type": "artist",
#                             "uri": "spotify:artist:1bT7m67vi78r2oqvxrP3X5"
#                         },
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI",
#                             "id": "2wY79sveU1sp5g7SokKOiI",
#                             "name": "Sam Smith",
#                             "type": "artist",
#                             "uri": "spotify:artist:2wY79sveU1sp5g7SokKOiI"
#                         }
#                     ],
#                     "available_markets": [
#                         "CA",
#                         "MX",
#                         "US"
#                     ],
#                     "disc_number": 1,
#                     "duration_ms": 222200,
#                     "episode": false,
#                     "explicit": false,
#                     "external_ids": {
#                         "isrc": "GBAAA1300148"
#                     },
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/track/36pLU2ywVeBKEF0rrKtmCB"
#                     },
#                     "href": "https://api.spotify.com/v1/tracks/36pLU2ywVeBKEF0rrKtmCB",
#                     "id": "36pLU2ywVeBKEF0rrKtmCB",
#                     "is_local": false,
#                     "name": "La La La",
#                     "popularity": 60,
#                     "preview_url": null,
#                     "track": true,
#                     "track_number": 8,
#                     "type": "track",
#                     "uri": "spotify:track:36pLU2ywVeBKEF0rrKtmCB"
#                 },
#                 "video_thumbnail": {
#                     "url": null
#                 }
#             },
#             {
#                 "added_at": "2017-08-03T23:41:15Z",
#                 "added_by": {
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/user/exiedous"
#                     },
#                     "href": "https://api.spotify.com/v1/users/exiedous",
#                     "id": "exiedous",
#                     "type": "user",
#                     "uri": "spotify:user:exiedous"
#                 },
#                 "is_local": false,
#                 "primary_color": null,
#                 "track": {
#                     "album": {
#                         "album_type": "album",
#                         "artists": [
#                             {
#                                 "external_urls": {
#                                     "spotify": "https://open.spotify.com/artist/1Cs0zKBU1kc0i8ypK3B9ai"
#                                 },
#                                 "href": "https://api.spotify.com/v1/artists/1Cs0zKBU1kc0i8ypK3B9ai",
#                                 "id": "1Cs0zKBU1kc0i8ypK3B9ai",
#                                 "name": "David Guetta",
#                                 "type": "artist",
#                                 "uri": "spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai"
#                             }
#                         ],
#                         "available_markets": [
#                             "GB",
#                             "IE"
#                         ],
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/album/1fAn5gw4Q5HN8Wpx2neYd2"
#                         },
#                         "href": "https://api.spotify.com/v1/albums/1fAn5gw4Q5HN8Wpx2neYd2",
#                         "id": "1fAn5gw4Q5HN8Wpx2neYd2",
#                         "images": [
#                             {
#                                 "height": 640,
#                                 "url": "https://i.scdn.co/image/ab67616d0000b273bd5ba80ea2ad342e488ba54d",
#                                 "width": 640
#                             },
#                             {
#                                 "height": 300,
#                                 "url": "https://i.scdn.co/image/ab67616d00001e02bd5ba80ea2ad342e488ba54d",
#                                 "width": 300
#                             },
#                             {
#                                 "height": 64,
#                                 "url": "https://i.scdn.co/image/ab67616d00004851bd5ba80ea2ad342e488ba54d",
#                                 "width": 64
#                             }
#                         ],
#                         "name": "Nothing but the Beat Ultimate",
#                         "release_date": "2011-08-26",
#                         "release_date_precision": "day",
#                         "total_tracks": 30,
#                         "type": "album",
#                         "uri": "spotify:album:1fAn5gw4Q5HN8Wpx2neYd2"
#                     },
#                     "artists": [
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/1Cs0zKBU1kc0i8ypK3B9ai"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/1Cs0zKBU1kc0i8ypK3B9ai",
#                             "id": "1Cs0zKBU1kc0i8ypK3B9ai",
#                             "name": "David Guetta",
#                             "type": "artist",
#                             "uri": "spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai"
#                         }
#                     ],
# ...
#                     "id": "7g9UjIFjs7KihId4XgIWQI",
#                     "is_local": false,
#                     "name": "Ebony Eyes (feat. A-Class & Sean Paul) - Original Edit",
#                     "popularity": 31,
#                     "preview_url": "https://p.scdn.co/mp3-preview/7f54af495250a054455ec766ecb5c60bb8575bd1?cid=c39fbc66489441ce809290f1c586c0db",
#                     "track": true,
#                     "track_number": 1,
#                     "type": "track",
#                     "uri": "spotify:track:7g9UjIFjs7KihId4XgIWQI"
#                 },
#                 "video_thumbnail": {
#                     "url": null
#                 }
#             },
#             {
#                 "added_at": "2017-08-03T23:54:43Z",
#                 "added_by": {
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/user/exiedous"
#                     },
#                     "href": "https://api.spotify.com/v1/users/exiedous",
#                     "id": "exiedous",
#                     "type": "user",
#                     "uri": "spotify:user:exiedous"
#                 },
#                 "is_local": false,
#                 "primary_color": null,
#                 "track": {
#                     "album": {
#                         "album_type": "single",
#                         "artists": [
#                             {
#                                 "external_urls": {
#                                     "spotify": "https://open.spotify.com/artist/49CE2ffZ6Z3zeYSDauSKck"
#                                 },
#                                 "href": "https://api.spotify.com/v1/artists/49CE2ffZ6Z3zeYSDauSKck",
#                                 "id": "49CE2ffZ6Z3zeYSDauSKck",
#                                 "name": "Tungevaag",
#                                 "type": "artist",
#                                 "uri": "spotify:artist:49CE2ffZ6Z3zeYSDauSKck"
#                             }
#                         ],
#                         "available_markets": [
#                             "DK",
#                             "FI",
#                             "SE"
#                         ],
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/album/0sto8hJizRoPKSQoFo57d9"
#                         },
#                         "href": "https://api.spotify.com/v1/albums/0sto8hJizRoPKSQoFo57d9",
#                         "id": "0sto8hJizRoPKSQoFo57d9",
#                         "images": [
#                             {
#                                 "height": 640,
#                                 "url": "https://i.scdn.co/image/ab67616d0000b273d76254f0ca18b1c7ae668b9f",
#                                 "width": 640
#                             },
#                             {
#                                 "height": 300,
#                                 "url": "https://i.scdn.co/image/ab67616d00001e02d76254f0ca18b1c7ae668b9f",
#                                 "width": 300
#                             },
#                             {
#                                 "height": 64,
#                                 "url": "https://i.scdn.co/image/ab67616d00004851d76254f0ca18b1c7ae668b9f",
#                                 "width": 64
#                             }
#                         ],
#                         "name": "Wicked Wonderland",
#                         "release_date": "2014-07-01",
#                         "release_date_precision": "day",
#                         "total_tracks": 2,
#                         "type": "album",
#                         "uri": "spotify:album:0sto8hJizRoPKSQoFo57d9"
#                     },
#                     "artists": [
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/49CE2ffZ6Z3zeYSDauSKck"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/49CE2ffZ6Z3zeYSDauSKck",
#                             "id": "49CE2ffZ6Z3zeYSDauSKck",
#                             "name": "Tungevaag",
#                             "type": "artist",
#                             "uri": "spotify:artist:49CE2ffZ6Z3zeYSDauSKck"
#                         }
#                     ],
#                     "available_markets": [
#                         "DK",
#                         "FI",
#                         "SE"
#                     ],
#                     "disc_number": 1,
#                     "duration_ms": 217270,
#                     "episode": false,
#                     "explicit": false,
#                     "external_ids": {
#                         "isrc": "DEN061401029"
#                     },
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/track/0zQXwzM2gtGfClqBBTsKXp"
#                     },
#                     "href": "https://api.spotify.com/v1/tracks/0zQXwzM2gtGfClqBBTsKXp",
#                     "id": "0zQXwzM2gtGfClqBBTsKXp",
#                     "is_local": false,
#                     "name": "Wicked Wonderland",
#                     "popularity": 49,
#                     "preview_url": "https://p.scdn.co/mp3-preview/5a5e0b6cb5a33d312edafe8ed0c823eb74f8629a?cid=c39fbc66489441ce809290f1c586c0db",
#                     "track": true,
#                     "track_number": 1,
#                     "type": "track",
#                     "uri": "spotify:track:0zQXwzM2gtGfClqBBTsKXp"
#                 },
#                 "video_thumbnail": {
#                     "url": null
#                 }
#             },
#             {
#                 "added_at": "2017-08-03T23:54:44Z",
#                 "added_by": {
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/user/exiedous"
#                     },
#                     "href": "https://api.spotify.com/v1/users/exiedous",
#                     "id": "exiedous",
#                     "type": "user",
#                     "uri": "spotify:user:exiedous"
#                 },
#                 "is_local": false,
#                 "primary_color": null,
#                 "track": {
#                     "album": {
#                         "album_type": "single",
#                         "artists": [
#                             {
#                                 "external_urls": {
#                                     "spotify": "https://open.spotify.com/artist/0dntlyBuGEEeteZIycDkrz"
#                                 },
#                                 "href": "https://api.spotify.com/v1/artists/0dntlyBuGEEeteZIycDkrz",
#                                 "id": "0dntlyBuGEEeteZIycDkrz",
#                                 "name": "Fun[k]House",
#                                 "type": "artist",
#                                 "uri": "spotify:artist:0dntlyBuGEEeteZIycDkrz"
#                             }
#                         ],
#                         "available_markets": [
#                             "DK",
#                             "FI",
#                             "IS",
#                             "NO",
#                             "SE"
#                         ],
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/album/6TKAikyAcp2yyRZfZPNr05"
#                         },
#                         "href": "https://api.spotify.com/v1/albums/6TKAikyAcp2yyRZfZPNr05",
#                         "id": "6TKAikyAcp2yyRZfZPNr05",
#                         "images": [
#                             {
#                                 "height": 640,
#                                 "url": "https://i.scdn.co/image/ab67616d0000b273fc299ec9615101387071b630",
#                                 "width": 640
#                             },
#                             {
#                                 "height": 300,
#                                 "url": "https://i.scdn.co/image/ab67616d00001e02fc299ec9615101387071b630",
#                                 "width": 300
#                             },
#                             {
#                                 "height": 64,
#                                 "url": "https://i.scdn.co/image/ab67616d00004851fc299ec9615101387071b630",
#                                 "width": 64
#                             }
#                         ],
#                         "name": "Freed From Desire",
#                         "release_date": "2013-07-22",
#                         "release_date_precision": "day",
#                         "total_tracks": 6,
#                         "type": "album",
#                         "uri": "spotify:album:6TKAikyAcp2yyRZfZPNr05"
#                     },
#                     "artists": [
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/0dntlyBuGEEeteZIycDkrz"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/0dntlyBuGEEeteZIycDkrz",
#                             "id": "0dntlyBuGEEeteZIycDkrz",
#                             "name": "Fun[k]House",
#                             "type": "artist",
#                             "uri": "spotify:artist:0dntlyBuGEEeteZIycDkrz"
#                         }
#                     ],
#                     "available_markets": [
#                         "DK",
#                         "FI",
#                         "IS",
#                         "NO",
#                         "SE"
#                     ],
#                     "disc_number": 1,
#                     "duration_ms": 183089,
#                     "episode": false,
#                     "explicit": false,
#                     "external_ids": {
#                         "isrc": "DENY51000085"
#                     },
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/track/3V3BtIfN5FwhnnaV5a6xAu"
#                     },
#                     "href": "https://api.spotify.com/v1/tracks/3V3BtIfN5FwhnnaV5a6xAu",
#                     "id": "3V3BtIfN5FwhnnaV5a6xAu",
#                     "is_local": false,
#                     "name": "Freed From Desire - Radio Edit",
#                     "popularity": 34,
#                     "preview_url": "https://p.scdn.co/mp3-preview/e946eef014f08938c212f6ed4b6e719bef7942ff?cid=c39fbc66489441ce809290f1c586c0db",
#                     "track": true,
#                     "track_number": 1,
#                     "type": "track",
#                     "uri": "spotify:track:3V3BtIfN5FwhnnaV5a6xAu"
#                 },
#                 "video_thumbnail": {
#                     "url": null
#                 }
#             },
#             {
#                 "added_at": "2017-08-03T23:54:46Z",
#                 "added_by": {
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/user/exiedous"
#                     },
#                     "href": "https://api.spotify.com/v1/users/exiedous",
#                     "id": "exiedous",
#                     "type": "user",
#                     "uri": "spotify:user:exiedous"
#                 },
#                 "is_local": false,
#                 "primary_color": null,
#                 "track": {
#                     "album": {
#                         "album_type": "single",
#                         "artists": [
#                             {
#                                 "external_urls": {
#                                     "spotify": "https://open.spotify.com/artist/5nkYRuiIHg2xXHFC8bfosJ"
#                                 },
#                                 "href": "https://api.spotify.com/v1/artists/5nkYRuiIHg2xXHFC8bfosJ",
#                                 "id": "5nkYRuiIHg2xXHFC8bfosJ",
#                                 "name": "ItaloBrothers",
#                                 "type": "artist",
#                                 "uri": "spotify:artist:5nkYRuiIHg2xXHFC8bfosJ"
#                             }
#                         ],
#                         "available_markets": [],
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/album/0dmp6vTMqHVwsGWpYryO9m"
#                         },
#                         "href": "https://api.spotify.com/v1/albums/0dmp6vTMqHVwsGWpYryO9m",
#                         "id": "0dmp6vTMqHVwsGWpYryO9m",
#                         "images": [
#                             {
#                                 "height": 640,
#                                 "url": "https://i.scdn.co/image/ab67616d0000b273b5fff14cb0dabeaf1d3fb7aa",
#                                 "width": 640
#                             },
#                             {
#                                 "height": 300,
#                                 "url": "https://i.scdn.co/image/ab67616d00001e02b5fff14cb0dabeaf1d3fb7aa",
#                                 "width": 300
#                             },
#                             {
#                                 "height": 64,
#                                 "url": "https://i.scdn.co/image/ab67616d00004851b5fff14cb0dabeaf1d3fb7aa",
#                                 "width": 64
#                             }
#                         ],
#                         "name": "Boom (feat. Carlprit)",
#                         "release_date": "2012-12-21",
#                         "release_date_precision": "day",
#                         "total_tracks": 4,
#                         "type": "album",
#                         "uri": "spotify:album:0dmp6vTMqHVwsGWpYryO9m"
#                     },
#                     "artists": [
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/5nkYRuiIHg2xXHFC8bfosJ"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/5nkYRuiIHg2xXHFC8bfosJ",
#                             "id": "5nkYRuiIHg2xXHFC8bfosJ",
#                             "name": "ItaloBrothers",
#                             "type": "artist",
#                             "uri": "spotify:artist:5nkYRuiIHg2xXHFC8bfosJ"
#                         },
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/0Wj6u7zMY2dOLkJGz62bEp"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/0Wj6u7zMY2dOLkJGz62bEp",
#                             "id": "0Wj6u7zMY2dOLkJGz62bEp",
#                             "name": "Carlprit",
#                             "type": "artist",
#                             "uri": "spotify:artist:0Wj6u7zMY2dOLkJGz62bEp"
#                         }
#                     ],
#                     "available_markets": [],
#                     "disc_number": 1,
#                     "duration_ms": 191169,
#                     "episode": false,
#                     "explicit": false,
#                     "external_ids": {
#                         "isrc": "DEHK91142201"
#                     },
#                     "external_urls": {
#                         "spotify": "https://open.spotify.com/track/0dZ5AOJd3E9SUrPeKYeMbK"
#                     },
#                     "href": "https://api.spotify.com/v1/tracks/0dZ5AOJd3E9SUrPeKYeMbK",
#                     "id": "0dZ5AOJd3E9SUrPeKYeMbK",
#                     "is_local": false,
#                     "name": "Boom (feat. Carlprit) - Video Edit",
#                     "popularity": 0,
#                     "preview_url": null,
#                     "track": true,
#                     "track_number": 1,
#                     "type": "track",
#                     "uri": "spotify:track:0dZ5AOJd3E9SUrPeKYeMbK"
#                 },
#                 "video_thumbnail": {
#                     "url": null
#                 }
#             }
#         ],
#         "limit": 100,
#         "next": "https://api.spotify.com/v1/playlists/6FKDzNYZ8IW1pvYVF4zUN2/tracks?offset=100&limit=100&additional_types=track",
#         "offset": 0,
#         "previous": null,
#         "total": 10000
#     },
#     "type": "playlist",
#     "uri": "spotify:playlist:6FKDzNYZ8IW1pvYVF4zUN2"
# }

# %%
#capture features of your own playlists into a df - enter your id and playlist id

playlist = sp.user_playlist("exiedous", "6FKDzNYZ8IW1pvYVF4zUN2") 
songs = playlist["tracks"]["items"] 
ids = [] 
for i in range(len(songs)): 
    ids.append(songs[i]["track"]["id"]) 
features = sp.audio_features(ids) 
df = pd.DataFrame(features)
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.647   0.933    7    -4.056     1       0.1110      0.000351
# 1         0.733   0.818   10    -7.222     0       0.0859      0.024100
# 2         0.692   0.711    0    -7.498     0       0.0317      0.225000
# 3         0.327   0.895    9    -7.428     1       0.0367      0.000564
# 4         0.760   0.652    6    -7.321     1       0.2320      0.034800
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0           0.00277    0.3340    0.332  119.921  audio_features
# 1           0.00000    0.0636    0.253  116.019  audio_features
# 2           0.00000    0.1200    0.875  125.135  audio_features
# 3           0.01590    0.1040    0.898  169.390  audio_features
# 4           0.00000    0.3070    0.759  100.315  audio_features
#
#                        id                                   uri  \
# 0  6pGUGTIaZ1H4jKHIL4Fged  spotify:track:6pGUGTIaZ1H4jKHIL4Fged
# 1  09TcIuH1ZO7i4vicWKoaN2  spotify:track:09TcIuH1ZO7i4vicWKoaN2
# 2  1TfqLAPs4K3s2rJMoCokcS  spotify:track:1TfqLAPs4K3s2rJMoCokcS
# 3  3w2GGz0HjIu9OcWXINRFJR  spotify:track:3w2GGz0HjIu9OcWXINRFJR
# 4  4X4tgBEUiT6WqB2oTJ5ynH  spotify:track:4X4tgBEUiT6WqB2oTJ5ynH
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6pGUGTIaZ1H4...
# 1  https://api.spotify.com/v1/tracks/09TcIuH1ZO7i...
# 2  https://api.spotify.com/v1/tracks/1TfqLAPs4K3s...
# 3  https://api.spotify.com/v1/tracks/3w2GGz0HjIu9...
# 4  https://api.spotify.com/v1/tracks/4X4tgBEUiT6W...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6pGU...       235107
# 1  https://api.spotify.com/v1/audio-analysis/09Tc...       232147
# 2  https://api.spotify.com/v1/audio-analysis/1Tfq...       216933
# 3  https://api.spotify.com/v1/audio-analysis/3w2G...       219800
# 4  https://api.spotify.com/v1/audio-analysis/4X4t...       177685
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
#or define from a public playlist

playlist = sp.user_playlist_tracks("spotify", "6FKDzNYZ8IW1pvYVF4zUN2")

# %%
#check its working - first track 
playlist["items"][0]["track"]["uri"]
# Out:
# 'spotify:track:6pGUGTIaZ1H4jKHIL4Fged'

# %%
for song in playlist["items"]:
    print(song.keys())
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
#how many songs on that playlist?
playlist["total"]
# Out:
# 10000

# %%
#function to get tracks from playlist 

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks = get_playlist_tracks("6FKDzNYZ8IW1pvYVF4zUN2")

# %% [markdown]
# ### Audio features
#
# You can check here an explanation of the audio features: https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/

# %%
#get the results of a playlist
playlist = sp.user_playlist_tracks("spotify", "36UuuONPIdnKZykWOt2Poz")

# %%
# get the uri of a single song:
song_uri = playlist["items"][0]["track"]["uri"]

# %%
#by the way, what is that song ?
playlist["items"][0]["track"]["name"]

# %%
# get the audio features for that song
sp.audio_features(song_uri)

# %%
#function to extract all Uris from a playlist 
#- we already had the function to take the songs from the playlist 

def get_song_uris(playlist_id):
    tracks = get_playlist_tracks(playlist_id)
    uris = [track["track"]["uri"] for track in tracks]
    return uris

# %%
#part 2 of function

IH_uris = get_song_uris("36UuuONPIdnKZykWOt2Poz")

# %% [markdown]
# Above, we stored all the uri's of a playlist into a list called IH_uris. We're going to get all the audio features from that playlist's songs now.

# %%
aud_feat = []

for song in IH_uris:
    aud_feat.append(sp.audio_features(song))

# %%
#take a look at the features of all the songs in the playlist 

aud_feat

# %% [markdown]
# ### Searching the audio features for a song
#
# When the user inputs a song, you are gonna want to retrieve the audio features of that song. How to do it?
#
# 1. Search the user input using the `sp.search()` function. This function works similarly to the "search" bar on the spotify app - using Spotify's intelligent search engine. That means that it can handle names of any songs or artists - even certain typos.
#
# 2. Find the uri of the song that the API gives you back.
#
# 3. Use `sp.audio_features` to retrieve the audio features of the song.

# %%
#1 
usersearch = sp.search(q='bohemian', limit=1)

# %%
# 2
usersearch["tracks"]["items"][0]["uri"]

# %%
# 3
sp.audio_features(usersearch["tracks"]["items"][0]["uri"])

# %% [markdown]
# ### Lab: Create your collection of songs & audio features
#
# To move forward witht the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster.
#
# The more songs you have, the more accurate recommendations you'll be able to give. Although, you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!
